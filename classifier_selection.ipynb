# %%
import numpy as np
import re

# %%
import pickle
def save_obj(obj, name ):
    with open('data/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open('data/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
data = load_obj('posts_training_data')

# %%
features = np.array([list(feature.values()) for feature in data['feature']])
target = data['sentiment']
print(features.shape)
# Out:
# (338, 11)

# %%
for key in data['feature'][0].keys():
    print(key)
# Out:
# exclamation
# question_mark
# pos_vs_neg
# pos_strength
# pos_vs_neg_strength
# pos
# num_slang
# avg_word_len
# neg
# neg_strength
# number_number

# %%
from sklearn.grid_search import GridSearchCV
import csv
import os.path
from sklearn import preprocessing
def grid_search(clf, features_dict_list, target, param_grid, cv=None, 
                scoring=None, feature_scaled=False, output=True, output_file=None):
    if not cv:
        cv = 10
    if not scoring:
        scoring = 'accuracy'
    if not output_file:
        output = 'data/classifier_selection.csv'
    features = np.array([list(feature.values()) for feature in features_dict_list])
    if feature_scaled:
        features = preprocessing.scale(features)
    feature_names = ', '.join(features_dict_list[0].keys())
    gs_clf = GridSearchCV(estimator=clf, param_grid=param_grid,
                   n_jobs=-1, cv=cv,scoring=scoring)
    gs_clf.fit(features, target)
    grid_scores = gs_clf.grid_scores_
    # write training data to .csv
    file_exist = os.path.isfile(output) 
    if not file_exist and output:
        with open(output, 'w') as csvfile:
            writer = csv.writer(csvfile)

            writer.writerow(["classifier", "parameters", "features", "feature_scaled", 
                             "cv", "avg_accuracy", "std_accuracy"])
            for score in grid_scores: 
                params = score[0]
                avg_accuracy = score[1]
                std_accuracy = np.std(score[2])
                writer.writerow([type(clf).__name__, params, feature_names,
                                 feature_scaled, cv, avg_accuracy, std_accuracy])
    elif file_exist and output:
        with open(output, 'a') as csvfile:
            writer = csv.writer(csvfile)
            for score in grid_scores: 
                params = score[0]
                avg_accuracy = score[1]
                std_accuracy = np.std(score[2])
                writer.writerow([type(clf).__name__, params, feature_names,
                                 feature_scaled, cv, avg_accuracy, std_accuracy])
    else:
        pass
    print(gs_clf.best_score_)
    return gs_clf

# %% [markdown]
# ### Get subsets of feature dictionary

# %%
from itertools import chain, combinations
def all_subsets(ss):
  return(chain(*map(lambda x: combinations(ss, x), range(0, len(ss)+1))))

# %%
for subset in all_subsets(data['feature'][0].keys()):
  print(list[sub)
# Out:
# ()
# ('exclamation',)
# ('question_mark',)
# ('pos_vs_neg',)
# ('pos_strength',)
# ('pos_vs_neg_strength',)
# ('pos',)
# ('num_slang',)
# ('avg_word_len',)
# ('neg',)
# ('neg_strength',)
# ('number_number',)
# ('exclamation', 'question_mark')
# ('exclamation', 'pos_vs_neg')
# ('exclamation', 'pos_strength')
# ('exclamation', 'pos_vs_neg_strength')
# ('exclamation', 'pos')
# ('exclamation', 'num_slang')
# ('exclamation', 'avg_word_len')
# ('exclamation', 'neg')
# ('exclamation', 'neg_strength')
# ('exclamation', 'number_number')
# ('question_mark', 'pos_vs_neg')
# ('question_mark', 'pos_strength')
# ('question_mark', 'pos_vs_neg_strength')
# ('question_mark', 'pos')
# ('question_mark', 'num_slang')
# ('question_mark', 'avg_word_len')
# ('question_mark', 'neg')
# ('question_mark', 'neg_strength')
# ('question_mark', 'number_number')
# ('pos_vs_neg', 'pos_strength')
# ('pos_vs_neg', 'pos_vs_neg_strength')
# ('pos_vs_neg', 'pos')
# ('pos_vs_neg', 'num_slang')
# ('pos_vs_neg', 'avg_word_len')
# ('pos_vs_neg', 'neg')
# ('pos_vs_neg', 'neg_strength')
# ('pos_vs_neg', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength')
# ('pos_strength', 'pos')
# ('pos_strength', 'num_slang')
# ('pos_strength', 'avg_word_len')
# ('pos_strength', 'neg')
# ('pos_strength', 'neg_strength')
# ('pos_strength', 'number_number')
# ('pos_vs_neg_strength', 'pos')
# ('pos_vs_neg_strength', 'num_slang')
# ('pos_vs_neg_strength', 'avg_word_len')
# ('pos_vs_neg_strength', 'neg')
# ('pos_vs_neg_strength', 'neg_strength')
# ('pos_vs_neg_strength', 'number_number')
# ('pos', 'num_slang')
# ('pos', 'avg_word_len')
# ('pos', 'neg')
# ('pos', 'neg_strength')
# ('pos', 'number_number')
# ('num_slang', 'avg_word_len')
# ('num_slang', 'neg')
# ('num_slang', 'neg_strength')
# ('num_slang', 'number_number')
# ('avg_word_len', 'neg')
# ('avg_word_len', 'neg_strength')
# ('avg_word_len', 'number_number')
# ('neg', 'neg_strength')
# ('neg', 'number_number')
# ('neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg')
# ('exclamation', 'question_mark', 'pos_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength')
# ('exclamation', 'question_mark', 'pos')
# ('exclamation', 'question_mark', 'num_slang')
# ('exclamation', 'question_mark', 'avg_word_len')
# ('exclamation', 'question_mark', 'neg')
# ('exclamation', 'question_mark', 'neg_strength')
# ('exclamation', 'question_mark', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos')
# ('exclamation', 'pos_vs_neg', 'num_slang')
# ('exclamation', 'pos_vs_neg', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'neg')
# ('exclamation', 'pos_vs_neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength')
# ('exclamation', 'pos_strength', 'pos')
# ('exclamation', 'pos_strength', 'num_slang')
# ('exclamation', 'pos_strength', 'avg_word_len')
# ('exclamation', 'pos_strength', 'neg')
# ('exclamation', 'pos_strength', 'neg_strength')
# ('exclamation', 'pos_strength', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'pos')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang')
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len')
# ('exclamation', 'pos_vs_neg_strength', 'neg')
# ('exclamation', 'pos_vs_neg_strength', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'number_number')
# ('exclamation', 'pos', 'num_slang')
# ('exclamation', 'pos', 'avg_word_len')
# ('exclamation', 'pos', 'neg')
# ('exclamation', 'pos', 'neg_strength')
# ('exclamation', 'pos', 'number_number')
# ('exclamation', 'num_slang', 'avg_word_len')
# ('exclamation', 'num_slang', 'neg')
# ('exclamation', 'num_slang', 'neg_strength')
# ('exclamation', 'num_slang', 'number_number')
# ('exclamation', 'avg_word_len', 'neg')
# ('exclamation', 'avg_word_len', 'neg_strength')
# ('exclamation', 'avg_word_len', 'number_number')
# ('exclamation', 'neg', 'neg_strength')
# ('exclamation', 'neg', 'number_number')
# ('exclamation', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos')
# ('question_mark', 'pos_vs_neg', 'num_slang')
# ('question_mark', 'pos_vs_neg', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'neg')
# ('question_mark', 'pos_vs_neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength')
# ('question_mark', 'pos_strength', 'pos')
# ('question_mark', 'pos_strength', 'num_slang')
# ('question_mark', 'pos_strength', 'avg_word_len')
# ('question_mark', 'pos_strength', 'neg')
# ('question_mark', 'pos_strength', 'neg_strength')
# ('question_mark', 'pos_strength', 'number_number')
# ('question_mark', 'pos_vs_neg_strength', 'pos')
# ('question_mark', 'pos_vs_neg_strength', 'num_slang')
# ('question_mark', 'pos_vs_neg_strength', 'avg_word_len')
# ('question_mark', 'pos_vs_neg_strength', 'neg')
# ('question_mark', 'pos_vs_neg_strength', 'neg_strength')
# ('question_mark', 'pos_vs_neg_strength', 'number_number')
# ('question_mark', 'pos', 'num_slang')
# ('question_mark', 'pos', 'avg_word_len')
# ('question_mark', 'pos', 'neg')
# ('question_mark', 'pos', 'neg_strength')
# ('question_mark', 'pos', 'number_number')
# ('question_mark', 'num_slang', 'avg_word_len')
# ('question_mark', 'num_slang', 'neg')
# ('question_mark', 'num_slang', 'neg_strength')
# ('question_mark', 'num_slang', 'number_number')
# ('question_mark', 'avg_word_len', 'neg')
# ('question_mark', 'avg_word_len', 'neg_strength')
# ('question_mark', 'avg_word_len', 'number_number')
# ('question_mark', 'neg', 'neg_strength')
# ('question_mark', 'neg', 'number_number')
# ('question_mark', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength')
# ('pos_vs_neg', 'pos_strength', 'pos')
# ('pos_vs_neg', 'pos_strength', 'num_slang')
# ('pos_vs_neg', 'pos_strength', 'avg_word_len')
# ('pos_vs_neg', 'pos_strength', 'neg')
# ('pos_vs_neg', 'pos_strength', 'neg_strength')
# ('pos_vs_neg', 'pos_strength', 'number_number')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'neg')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'number_number')
# ('pos_vs_neg', 'pos', 'num_slang')
# ('pos_vs_neg', 'pos', 'avg_word_len')
# ('pos_vs_neg', 'pos', 'neg')
# ('pos_vs_neg', 'pos', 'neg_strength')
# ('pos_vs_neg', 'pos', 'number_number')
# ('pos_vs_neg', 'num_slang', 'avg_word_len')
# ('pos_vs_neg', 'num_slang', 'neg')
# ('pos_vs_neg', 'num_slang', 'neg_strength')
# ('pos_vs_neg', 'num_slang', 'number_number')
# ('pos_vs_neg', 'avg_word_len', 'neg')
# ('pos_vs_neg', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg', 'avg_word_len', 'number_number')
# ('pos_vs_neg', 'neg', 'neg_strength')
# ('pos_vs_neg', 'neg', 'number_number')
# ('pos_vs_neg', 'neg_strength', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength', 'pos')
# ('pos_strength', 'pos_vs_neg_strength', 'num_slang')
# ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# ('pos_strength', 'pos_vs_neg_strength', 'neg')
# ('pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# ('pos_strength', 'pos_vs_neg_strength', 'number_number')
# ('pos_strength', 'pos', 'num_slang')
# ('pos_strength', 'pos', 'avg_word_len')
# ('pos_strength', 'pos', 'neg')
# ('pos_strength', 'pos', 'neg_strength')
# ('pos_strength', 'pos', 'number_number')
# ('pos_strength', 'num_slang', 'avg_word_len')
# ('pos_strength', 'num_slang', 'neg')
# ('pos_strength', 'num_slang', 'neg_strength')
# ('pos_strength', 'num_slang', 'number_number')
# ('pos_strength', 'avg_word_len', 'neg')
# ('pos_strength', 'avg_word_len', 'neg_strength')
# ('pos_strength', 'avg_word_len', 'number_number')
# ('pos_strength', 'neg', 'neg_strength')
# ('pos_strength', 'neg', 'number_number')
# ('pos_strength', 'neg_strength', 'number_number')
# ('pos_vs_neg_strength', 'pos', 'num_slang')
# ('pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('pos_vs_neg_strength', 'pos', 'neg')
# ('pos_vs_neg_strength', 'pos', 'neg_strength')
# ('pos_vs_neg_strength', 'pos', 'number_number')
# ('pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('pos_vs_neg_strength', 'num_slang', 'neg')
# ('pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('pos_vs_neg_strength', 'num_slang', 'number_number')
# ('pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('pos_vs_neg_strength', 'neg', 'neg_strength')
# ('pos_vs_neg_strength', 'neg', 'number_number')
# ('pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('pos', 'num_slang', 'avg_word_len')
# ('pos', 'num_slang', 'neg')
# ('pos', 'num_slang', 'neg_strength')
# ('pos', 'num_slang', 'number_number')
# ('pos', 'avg_word_len', 'neg')
# ('pos', 'avg_word_len', 'neg_strength')
# ('pos', 'avg_word_len', 'number_number')
# ('pos', 'neg', 'neg_strength')
# ('pos', 'neg', 'number_number')
# ('pos', 'neg_strength', 'number_number')
# ('num_slang', 'avg_word_len', 'neg')
# ('num_slang', 'avg_word_len', 'neg_strength')
# ('num_slang', 'avg_word_len', 'number_number')
# ('num_slang', 'neg', 'neg_strength')
# ('num_slang', 'neg', 'number_number')
# ('num_slang', 'neg_strength', 'number_number')
# ('avg_word_len', 'neg', 'neg_strength')
# ('avg_word_len', 'neg', 'number_number')
# ('avg_word_len', 'neg_strength', 'number_number')
# ('neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'pos')
# ('exclamation', 'question_mark', 'pos_strength', 'num_slang')
# ('exclamation', 'question_mark', 'pos_strength', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_strength', 'neg')
# ('exclamation', 'question_mark', 'pos_strength', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos', 'num_slang')
# ('exclamation', 'question_mark', 'pos', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos', 'neg')
# ('exclamation', 'question_mark', 'pos', 'neg_strength')
# ('exclamation', 'question_mark', 'pos', 'number_number')
# ('exclamation', 'question_mark', 'num_slang', 'avg_word_len')
# ('exclamation', 'question_mark', 'num_slang', 'neg')
# ('exclamation', 'question_mark', 'num_slang', 'neg_strength')
# ('exclamation', 'question_mark', 'num_slang', 'number_number')
# ('exclamation', 'question_mark', 'avg_word_len', 'neg')
# ('exclamation', 'question_mark', 'avg_word_len', 'neg_strength')
# ('exclamation', 'question_mark', 'avg_word_len', 'number_number')
# ('exclamation', 'question_mark', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos', 'num_slang')
# ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos', 'number_number')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'neg')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'number_number')
# ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos', 'num_slang')
# ('exclamation', 'pos_strength', 'pos', 'avg_word_len')
# ('exclamation', 'pos_strength', 'pos', 'neg')
# ('exclamation', 'pos_strength', 'pos', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos', 'number_number')
# ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_strength', 'num_slang', 'neg')
# ('exclamation', 'pos_strength', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_strength', 'num_slang', 'number_number')
# ('exclamation', 'pos_strength', 'avg_word_len', 'neg')
# ('exclamation', 'pos_strength', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_strength', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_strength', 'neg', 'neg_strength')
# ('exclamation', 'pos_strength', 'neg', 'number_number')
# ('exclamation', 'pos_strength', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('exclamation', 'pos', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos', 'num_slang', 'neg')
# ('exclamation', 'pos', 'num_slang', 'neg_strength')
# ('exclamation', 'pos', 'num_slang', 'number_number')
# ('exclamation', 'pos', 'avg_word_len', 'neg')
# ('exclamation', 'pos', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos', 'avg_word_len', 'number_number')
# ('exclamation', 'pos', 'neg', 'neg_strength')
# ('exclamation', 'pos', 'neg', 'number_number')
# ('exclamation', 'pos', 'neg_strength', 'number_number')
# ('exclamation', 'num_slang', 'avg_word_len', 'neg')
# ('exclamation', 'num_slang', 'avg_word_len', 'neg_strength')
# ('exclamation', 'num_slang', 'avg_word_len', 'number_number')
# ('exclamation', 'num_slang', 'neg', 'neg_strength')
# ('exclamation', 'num_slang', 'neg', 'number_number')
# ('exclamation', 'num_slang', 'neg_strength', 'number_number')
# ('exclamation', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos', 'num_slang')
# ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos', 'number_number')
# ('question_mark', 'pos_vs_neg', 'num_slang', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'num_slang', 'neg')
# ('question_mark', 'pos_vs_neg', 'num_slang', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'num_slang', 'number_number')
# ('question_mark', 'pos_vs_neg', 'avg_word_len', 'neg')
# ('question_mark', 'pos_vs_neg', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'avg_word_len', 'number_number')
# ('question_mark', 'pos_vs_neg', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'neg')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos', 'num_slang')
# ('question_mark', 'pos_strength', 'pos', 'avg_word_len')
# ('question_mark', 'pos_strength', 'pos', 'neg')
# ('question_mark', 'pos_strength', 'pos', 'neg_strength')
# ('question_mark', 'pos_strength', 'pos', 'number_number')
# ('question_mark', 'pos_strength', 'num_slang', 'avg_word_len')
# ('question_mark', 'pos_strength', 'num_slang', 'neg')
# ('question_mark', 'pos_strength', 'num_slang', 'neg_strength')
# ('question_mark', 'pos_strength', 'num_slang', 'number_number')
# ('question_mark', 'pos_strength', 'avg_word_len', 'neg')
# ('question_mark', 'pos_strength', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos_strength', 'avg_word_len', 'number_number')
# ('question_mark', 'pos_strength', 'neg', 'neg_strength')
# ('question_mark', 'pos_strength', 'neg', 'number_number')
# ('question_mark', 'pos_strength', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('question_mark', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('question_mark', 'pos_vs_neg_strength', 'pos', 'neg')
# ('question_mark', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('question_mark', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('question_mark', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('question_mark', 'pos', 'num_slang', 'avg_word_len')
# ('question_mark', 'pos', 'num_slang', 'neg')
# ('question_mark', 'pos', 'num_slang', 'neg_strength')
# ('question_mark', 'pos', 'num_slang', 'number_number')
# ('question_mark', 'pos', 'avg_word_len', 'neg')
# ('question_mark', 'pos', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos', 'avg_word_len', 'number_number')
# ('question_mark', 'pos', 'neg', 'neg_strength')
# ('question_mark', 'pos', 'neg', 'number_number')
# ('question_mark', 'pos', 'neg_strength', 'number_number')
# ('question_mark', 'num_slang', 'avg_word_len', 'neg')
# ('question_mark', 'num_slang', 'avg_word_len', 'neg_strength')
# ('question_mark', 'num_slang', 'avg_word_len', 'number_number')
# ('question_mark', 'num_slang', 'neg', 'neg_strength')
# ('question_mark', 'num_slang', 'neg', 'number_number')
# ('question_mark', 'num_slang', 'neg_strength', 'number_number')
# ('question_mark', 'avg_word_len', 'neg', 'neg_strength')
# ('question_mark', 'avg_word_len', 'neg', 'number_number')
# ('question_mark', 'avg_word_len', 'neg_strength', 'number_number')
# ('question_mark', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang')
# ('pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len')
# ('pos_vs_neg', 'pos_strength', 'pos', 'neg')
# ('pos_vs_neg', 'pos_strength', 'pos', 'neg_strength')
# ('pos_vs_neg', 'pos_strength', 'pos', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len')
# ('pos_vs_neg', 'pos_strength', 'num_slang', 'neg')
# ('pos_vs_neg', 'pos_strength', 'num_slang', 'neg_strength')
# ('pos_vs_neg', 'pos_strength', 'num_slang', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg')
# ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'neg', 'neg_strength')
# ('pos_vs_neg', 'pos_strength', 'neg', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos', 'num_slang', 'avg_word_len')
# ('pos_vs_neg', 'pos', 'num_slang', 'neg')
# ('pos_vs_neg', 'pos', 'num_slang', 'neg_strength')
# ('pos_vs_neg', 'pos', 'num_slang', 'number_number')
# ('pos_vs_neg', 'pos', 'avg_word_len', 'neg')
# ('pos_vs_neg', 'pos', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg', 'pos', 'avg_word_len', 'number_number')
# ('pos_vs_neg', 'pos', 'neg', 'neg_strength')
# ('pos_vs_neg', 'pos', 'neg', 'number_number')
# ('pos_vs_neg', 'pos', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'num_slang', 'avg_word_len', 'neg')
# ('pos_vs_neg', 'num_slang', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg', 'num_slang', 'avg_word_len', 'number_number')
# ('pos_vs_neg', 'num_slang', 'neg', 'neg_strength')
# ('pos_vs_neg', 'num_slang', 'neg', 'number_number')
# ('pos_vs_neg', 'num_slang', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'avg_word_len', 'neg', 'neg_strength')
# ('pos_vs_neg', 'avg_word_len', 'neg', 'number_number')
# ('pos_vs_neg', 'avg_word_len', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'neg', 'neg_strength', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('pos_strength', 'pos_vs_neg_strength', 'pos', 'neg')
# ('pos_strength', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('pos_strength', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('pos_strength', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('pos_strength', 'pos', 'num_slang', 'avg_word_len')
# ('pos_strength', 'pos', 'num_slang', 'neg')
# ('pos_strength', 'pos', 'num_slang', 'neg_strength')
# ('pos_strength', 'pos', 'num_slang', 'number_number')
# ('pos_strength', 'pos', 'avg_word_len', 'neg')
# ('pos_strength', 'pos', 'avg_word_len', 'neg_strength')
# ('pos_strength', 'pos', 'avg_word_len', 'number_number')
# ('pos_strength', 'pos', 'neg', 'neg_strength')
# ('pos_strength', 'pos', 'neg', 'number_number')
# ('pos_strength', 'pos', 'neg_strength', 'number_number')
# ('pos_strength', 'num_slang', 'avg_word_len', 'neg')
# ('pos_strength', 'num_slang', 'avg_word_len', 'neg_strength')
# ('pos_strength', 'num_slang', 'avg_word_len', 'number_number')
# ('pos_strength', 'num_slang', 'neg', 'neg_strength')
# ('pos_strength', 'num_slang', 'neg', 'number_number')
# ('pos_strength', 'num_slang', 'neg_strength', 'number_number')
# ('pos_strength', 'avg_word_len', 'neg', 'neg_strength')
# ('pos_strength', 'avg_word_len', 'neg', 'number_number')
# ('pos_strength', 'avg_word_len', 'neg_strength', 'number_number')
# ('pos_strength', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len')
# ('pos_vs_neg_strength', 'pos', 'num_slang', 'neg')
# ('pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength')
# ('pos_vs_neg_strength', 'pos', 'num_slang', 'number_number')
# ('pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg')
# ('pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg_strength', 'pos', 'avg_word_len', 'number_number')
# ('pos_vs_neg_strength', 'pos', 'neg', 'neg_strength')
# ('pos_vs_neg_strength', 'pos', 'neg', 'number_number')
# ('pos_vs_neg_strength', 'pos', 'neg_strength', 'number_number')
# ('pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg')
# ('pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg_strength')
# ('pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'number_number')
# ('pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength')
# ('pos_vs_neg_strength', 'num_slang', 'neg', 'number_number')
# ('pos_vs_neg_strength', 'num_slang', 'neg_strength', 'number_number')
# ('pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength')
# ('pos_vs_neg_strength', 'avg_word_len', 'neg', 'number_number')
# ('pos_vs_neg_strength', 'avg_word_len', 'neg_strength', 'number_number')
# ('pos_vs_neg_strength', 'neg', 'neg_strength', 'number_number')
# ('pos', 'num_slang', 'avg_word_len', 'neg')
# ('pos', 'num_slang', 'avg_word_len', 'neg_strength')
# ('pos', 'num_slang', 'avg_word_len', 'number_number')
# ('pos', 'num_slang', 'neg', 'neg_strength')
# ('pos', 'num_slang', 'neg', 'number_number')
# ('pos', 'num_slang', 'neg_strength', 'number_number')
# ('pos', 'avg_word_len', 'neg', 'neg_strength')
# ('pos', 'avg_word_len', 'neg', 'number_number')
# ('pos', 'avg_word_len', 'neg_strength', 'number_number')
# ('pos', 'neg', 'neg_strength', 'number_number')
# ('num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('num_slang', 'avg_word_len', 'neg', 'number_number')
# ('num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('num_slang', 'neg', 'neg_strength', 'number_number')
# ('avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'num_slang')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'avg_word_len', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'avg_word_len', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'avg_word_len', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'neg')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos', 'num_slang')
# ('exclamation', 'question_mark', 'pos_strength', 'pos', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_strength', 'pos', 'neg')
# ('exclamation', 'question_mark', 'pos_strength', 'pos', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'pos', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'num_slang', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_strength', 'num_slang', 'neg')
# ('exclamation', 'question_mark', 'pos_strength', 'num_slang', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'num_slang', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'avg_word_len', 'neg')
# ('exclamation', 'question_mark', 'pos_strength', 'avg_word_len', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'avg_word_len', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos', 'num_slang', 'avg_word_len')
# ('exclamation', 'question_mark', 'pos', 'num_slang', 'neg')
# ('exclamation', 'question_mark', 'pos', 'num_slang', 'neg_strength')
# ('exclamation', 'question_mark', 'pos', 'num_slang', 'number_number')
# ('exclamation', 'question_mark', 'pos', 'avg_word_len', 'neg')
# ('exclamation', 'question_mark', 'pos', 'avg_word_len', 'neg_strength')
# ('exclamation', 'question_mark', 'pos', 'avg_word_len', 'number_number')
# ('exclamation', 'question_mark', 'pos', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'num_slang', 'avg_word_len', 'neg')
# ('exclamation', 'question_mark', 'num_slang', 'avg_word_len', 'neg_strength')
# ('exclamation', 'question_mark', 'num_slang', 'avg_word_len', 'number_number')
# ('exclamation', 'question_mark', 'num_slang', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'num_slang', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'num_slang', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg', 'num_slang', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_strength', 'pos', 'num_slang', 'neg')
# ('exclamation', 'pos_strength', 'pos', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos', 'num_slang', 'number_number')
# ('exclamation', 'pos_strength', 'pos', 'avg_word_len', 'neg')
# ('exclamation', 'pos_strength', 'pos', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_strength', 'pos', 'neg', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos', 'neg', 'number_number')
# ('exclamation', 'pos_strength', 'pos', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len', 'neg')
# ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_strength', 'num_slang', 'neg', 'neg_strength')
# ('exclamation', 'pos_strength', 'num_slang', 'neg', 'number_number')
# ('exclamation', 'pos_strength', 'num_slang', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'pos_strength', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'pos_strength', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos', 'num_slang', 'avg_word_len', 'neg')
# ('exclamation', 'pos', 'num_slang', 'avg_word_len', 'neg_strength')
# ('exclamation', 'pos', 'num_slang', 'avg_word_len', 'number_number')
# ('exclamation', 'pos', 'num_slang', 'neg', 'neg_strength')
# ('exclamation', 'pos', 'num_slang', 'neg', 'number_number')
# ('exclamation', 'pos', 'num_slang', 'neg_strength', 'number_number')
# ('exclamation', 'pos', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'pos', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'pos', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'pos', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len')
# ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos', 'neg', 'number_number')
# ...
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')

# %%
subsets_tuple = all_subsets(data['feature'][0].keys())
subsets = [subset for idx, subset in enumerate(subsets_tuple)]
subsets.pop(0)
# Out:
# ()

# %%
subsets
# Out:
# [('exclamation',),
#  ('question_mark',),
#  ('pos_vs_neg',),
#  ('pos_strength',),
#  ('pos_vs_neg_strength',),
#  ('pos',),
#  ('num_slang',),
#  ('avg_word_len',),
#  ('neg',),
#  ('neg_strength',),
#  ('number_number',),
#  ('exclamation', 'question_mark'),
#  ('exclamation', 'pos_vs_neg'),
#  ('exclamation', 'pos_strength'),
#  ('exclamation', 'pos_vs_neg_strength'),
#  ('exclamation', 'pos'),
#  ('exclamation', 'num_slang'),
#  ('exclamation', 'avg_word_len'),
#  ('exclamation', 'neg'),
#  ('exclamation', 'neg_strength'),
#  ('exclamation', 'number_number'),
#  ('question_mark', 'pos_vs_neg'),
#  ('question_mark', 'pos_strength'),
#  ('question_mark', 'pos_vs_neg_strength'),
#  ('question_mark', 'pos'),
#  ('question_mark', 'num_slang'),
#  ('question_mark', 'avg_word_len'),
#  ('question_mark', 'neg'),
#  ('question_mark', 'neg_strength'),
#  ('question_mark', 'number_number'),
#  ('pos_vs_neg', 'pos_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength'),
#  ('pos_vs_neg', 'pos'),
#  ('pos_vs_neg', 'num_slang'),
#  ('pos_vs_neg', 'avg_word_len'),
#  ('pos_vs_neg', 'neg'),
#  ('pos_vs_neg', 'neg_strength'),
#  ('pos_vs_neg', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength'),
#  ('pos_strength', 'pos'),
#  ('pos_strength', 'num_slang'),
#  ('pos_strength', 'avg_word_len'),
#  ('pos_strength', 'neg'),
#  ('pos_strength', 'neg_strength'),
#  ('pos_strength', 'number_number'),
#  ('pos_vs_neg_strength', 'pos'),
#  ('pos_vs_neg_strength', 'num_slang'),
#  ('pos_vs_neg_strength', 'avg_word_len'),
#  ('pos_vs_neg_strength', 'neg'),
#  ('pos_vs_neg_strength', 'neg_strength'),
#  ('pos_vs_neg_strength', 'number_number'),
#  ('pos', 'num_slang'),
#  ('pos', 'avg_word_len'),
#  ('pos', 'neg'),
#  ('pos', 'neg_strength'),
#  ('pos', 'number_number'),
#  ('num_slang', 'avg_word_len'),
#  ('num_slang', 'neg'),
#  ('num_slang', 'neg_strength'),
#  ('num_slang', 'number_number'),
#  ('avg_word_len', 'neg'),
#  ('avg_word_len', 'neg_strength'),
#  ('avg_word_len', 'number_number'),
#  ('neg', 'neg_strength'),
#  ('neg', 'number_number'),
#  ('neg_strength', 'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg'),
#  ('exclamation', 'question_mark', 'pos_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength'),
#  ('exclamation', 'question_mark', 'pos'),
#  ('exclamation', 'question_mark', 'num_slang'),
#  ('exclamation', 'question_mark', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'neg'),
#  ('exclamation', 'question_mark', 'neg_strength'),
#  ('exclamation', 'question_mark', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos'),
#  ('exclamation', 'pos_vs_neg', 'num_slang'),
#  ('exclamation', 'pos_vs_neg', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'number_number'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength'),
#  ('exclamation', 'pos_strength', 'pos'),
#  ('exclamation', 'pos_strength', 'num_slang'),
#  ('exclamation', 'pos_strength', 'avg_word_len'),
#  ('exclamation', 'pos_strength', 'neg'),
#  ('exclamation', 'pos_strength', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang'),
#  ('exclamation', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg_strength', 'neg'),
#  ('exclamation', 'pos_vs_neg_strength', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'number_number'),
#  ('exclamation', 'pos', 'num_slang'),
#  ('exclamation', 'pos', 'avg_word_len'),
#  ('exclamation', 'pos', 'neg'),
#  ('exclamation', 'pos', 'neg_strength'),
#  ('exclamation', 'pos', 'number_number'),
#  ('exclamation', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'num_slang', 'neg'),
#  ('exclamation', 'num_slang', 'neg_strength'),
#  ('exclamation', 'num_slang', 'number_number'),
#  ('exclamation', 'avg_word_len', 'neg'),
#  ('exclamation', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'avg_word_len', 'number_number'),
#  ('exclamation', 'neg', 'neg_strength'),
#  ('exclamation', 'neg', 'number_number'),
#  ('exclamation', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos'),
#  ('question_mark', 'pos_vs_neg', 'num_slang'),
#  ('question_mark', 'pos_vs_neg', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'number_number'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength'),
#  ('question_mark', 'pos_strength', 'pos'),
#  ('question_mark', 'pos_strength', 'num_slang'),
#  ('question_mark', 'pos_strength', 'avg_word_len'),
#  ('question_mark', 'pos_strength', 'neg'),
#  ('question_mark', 'pos_strength', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang'),
#  ('question_mark', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg_strength', 'neg'),
#  ('question_mark', 'pos_vs_neg_strength', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'number_number'),
#  ('question_mark', 'pos', 'num_slang'),
#  ('question_mark', 'pos', 'avg_word_len'),
#  ('question_mark', 'pos', 'neg'),
#  ('question_mark', 'pos', 'neg_strength'),
#  ('question_mark', 'pos', 'number_number'),
#  ('question_mark', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'num_slang', 'neg'),
#  ('question_mark', 'num_slang', 'neg_strength'),
#  ('question_mark', 'num_slang', 'number_number'),
#  ('question_mark', 'avg_word_len', 'neg'),
#  ('question_mark', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'avg_word_len', 'number_number'),
#  ('question_mark', 'neg', 'neg_strength'),
#  ('question_mark', 'neg', 'number_number'),
#  ('question_mark', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang'),
#  ('pos_vs_neg', 'pos_strength', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_strength', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'neg'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos', 'num_slang'),
#  ('pos_vs_neg', 'pos', 'avg_word_len'),
#  ('pos_vs_neg', 'pos', 'neg'),
#  ('pos_vs_neg', 'pos', 'neg_strength'),
#  ('pos_vs_neg', 'pos', 'number_number'),
#  ('pos_vs_neg', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg', 'num_slang', 'neg'),
#  ('pos_vs_neg', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg', 'num_slang', 'number_number'),
#  ('pos_vs_neg', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'neg', 'number_number'),
#  ('pos_vs_neg', 'neg_strength', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang'),
#  ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('pos_strength', 'pos_vs_neg_strength', 'neg'),
#  ('pos_strength', 'pos_vs_neg_strength', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'number_number'),
#  ('pos_strength', 'pos', 'num_slang'),
#  ('pos_strength', 'pos', 'avg_word_len'),
#  ('pos_strength', 'pos', 'neg'),
#  ('pos_strength', 'pos', 'neg_strength'),
#  ('pos_strength', 'pos', 'number_number'),
#  ('pos_strength', 'num_slang', 'avg_word_len'),
#  ('pos_strength', 'num_slang', 'neg'),
#  ('pos_strength', 'num_slang', 'neg_strength'),
#  ('pos_strength', 'num_slang', 'number_number'),
#  ('pos_strength', 'avg_word_len', 'neg'),
#  ('pos_strength', 'avg_word_len', 'neg_strength'),
#  ('pos_strength', 'avg_word_len', 'number_number'),
#  ('pos_strength', 'neg', 'neg_strength'),
#  ('pos_strength', 'neg', 'number_number'),
#  ('pos_strength', 'neg_strength', 'number_number'),
#  ('pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('pos_vs_neg_strength', 'pos', 'neg'),
#  ('pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('pos_vs_neg_strength', 'pos', 'number_number'),
#  ('pos_vs_neg_strength', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('pos_vs_neg_strength', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg_strength', 'num_slang', 'number_number'),
#  ('pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('pos_vs_neg_strength', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg_strength', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('pos_vs_neg_strength', 'neg', 'number_number'),
#  ('pos_vs_neg_strength', 'neg_strength', 'number_number'),
#  ('pos', 'num_slang', 'avg_word_len'),
#  ('pos', 'num_slang', 'neg'),
#  ('pos', 'num_slang', 'neg_strength'),
#  ('pos', 'num_slang', 'number_number'),
#  ('pos', 'avg_word_len', 'neg'),
#  ('pos', 'avg_word_len', 'neg_strength'),
#  ('pos', 'avg_word_len', 'number_number'),
#  ('pos', 'neg', 'neg_strength'),
#  ('pos', 'neg', 'number_number'),
#  ('pos', 'neg_strength', 'number_number'),
#  ('num_slang', 'avg_word_len', 'neg'),
#  ('num_slang', 'avg_word_len', 'neg_strength'),
#  ('num_slang', 'avg_word_len', 'number_number'),
#  ('num_slang', 'neg', 'neg_strength'),
#  ('num_slang', 'neg', 'number_number'),
#  ('num_slang', 'neg_strength', 'number_number'),
#  ('avg_word_len', 'neg', 'neg_strength'),
#  ('avg_word_len', 'neg', 'number_number'),
#  ('avg_word_len', 'neg_strength', 'number_number'),
#  ('neg', 'neg_strength', 'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'neg'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'number_number'),
#  ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength'),
#  ('exclamation', 'question_mark', 'pos_strength', 'pos'),
#  ('exclamation', 'question_mark', 'pos_strength', 'num_slang'),
#  ('exclamation', 'question_mark', 'pos_strength', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_strength', 'neg'),
#  ('exclamation', 'question_mark', 'pos_strength', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_strength', 'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'number_number'),
#  ('exclamation', 'question_mark', 'pos', 'num_slang'),
#  ('exclamation', 'question_mark', 'pos', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos', 'neg'),
#  ('exclamation', 'question_mark', 'pos', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos', 'number_number'),
#  ('exclamation', 'question_mark', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'num_slang', 'neg'),
#  ('exclamation', 'question_mark', 'num_slang', 'neg_strength'),
#  ('exclamation', 'question_mark', 'num_slang', 'number_number'),
#  ('exclamation', 'question_mark', 'avg_word_len', 'neg'),
#  ('exclamation', 'question_mark', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'question_mark', 'avg_word_len', 'number_number'),
#  ('exclamation', 'question_mark', 'neg', 'neg_strength'),
#  ('exclamation', 'question_mark', 'neg', 'number_number'),
#  ('exclamation', 'question_mark', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'num_slang'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'neg', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'number_number'),
#  ('exclamation', 'pos_strength', 'pos', 'num_slang'),
#  ('exclamation', 'pos_strength', 'pos', 'avg_word_len'),
#  ('exclamation', 'pos_strength', 'pos', 'neg'),
#  ('exclamation', 'pos_strength', 'pos', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'pos', 'number_number'),
#  ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos_strength', 'num_slang', 'neg'),
#  ('exclamation', 'pos_strength', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'num_slang', 'number_number'),
#  ('exclamation', 'pos_strength', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_strength', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos_strength', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'neg', 'number_number'),
#  ('exclamation', 'pos_strength', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'neg', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos', 'num_slang', 'neg'),
#  ('exclamation', 'pos', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos', 'num_slang', 'number_number'),
#  ('exclamation', 'pos', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos', 'neg', 'neg_strength'),
#  ('exclamation', 'pos', 'neg', 'number_number'),
#  ('exclamation', 'pos', 'neg_strength', 'number_number'),
#  ('exclamation', 'num_slang', 'avg_word_len', 'neg'),
#  ('exclamation', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'num_slang', 'avg_word_len', 'number_number'),
#  ('exclamation', 'num_slang', 'neg', 'neg_strength'),
#  ('exclamation', 'num_slang', 'neg', 'number_number'),
#  ('exclamation', 'num_slang', 'neg_strength', 'number_number'),
#  ('exclamation', 'avg_word_len', 'neg', 'neg_strength'),
#  ('exclamation', 'avg_word_len', 'neg', 'number_number'),
#  ('exclamation', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('exclamation', 'neg', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'num_slang'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'neg', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'neg'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'number_number'),
#  ('question_mark', 'pos_strength', 'pos', 'num_slang'),
#  ('question_mark', 'pos_strength', 'pos', 'avg_word_len'),
#  ('question_mark', 'pos_strength', 'pos', 'neg'),
#  ('question_mark', 'pos_strength', 'pos', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'pos', 'number_number'),
#  ('question_mark', 'pos_strength', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos_strength', 'num_slang', 'neg'),
#  ('question_mark', 'pos_strength', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'num_slang', 'number_number'),
#  ('question_mark', 'pos_strength', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos_strength', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos_strength', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'neg', 'number_number'),
#  ('question_mark', 'pos_strength', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'neg', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos', 'num_slang', 'neg'),
#  ('question_mark', 'pos', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos', 'num_slang', 'number_number'),
#  ('question_mark', 'pos', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos', 'neg', 'neg_strength'),
#  ('question_mark', 'pos', 'neg', 'number_number'),
#  ('question_mark', 'pos', 'neg_strength', 'number_number'),
#  ('question_mark', 'num_slang', 'avg_word_len', 'neg'),
#  ('question_mark', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'num_slang', 'avg_word_len', 'number_number'),
#  ('question_mark', 'num_slang', 'neg', 'neg_strength'),
#  ('question_mark', 'num_slang', 'neg', 'number_number'),
#  ('question_mark', 'num_slang', 'neg_strength', 'number_number'),
#  ('question_mark', 'avg_word_len', 'neg', 'neg_strength'),
#  ('question_mark', 'avg_word_len', 'neg', 'number_number'),
#  ('question_mark', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('question_mark', 'neg', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'neg'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'number_number'),
#  ('pos_vs_neg', 'pos', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'pos', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'pos', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'pos', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'num_slang', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'num_slang', 'neg', 'number_number'),
#  ('pos_vs_neg', 'num_slang', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_vs_neg', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'neg', 'neg_strength', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'neg', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'neg_strength', 'number_number'),
#  ('pos_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('pos_strength', 'pos', 'num_slang', 'neg'),
#  ('pos_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('pos_strength', 'pos', 'num_slang', 'number_number'),
#  ('pos_strength', 'pos', 'avg_word_len', 'neg'),
#  ('pos_strength', 'pos', 'avg_word_len', 'neg_strength'),
#  ('pos_strength', 'pos', 'avg_word_len', 'number_number'),
#  ('pos_strength', 'pos', 'neg', 'neg_strength'),
#  ('pos_strength', 'pos', 'neg', 'number_number'),
#  ('pos_strength', 'pos', 'neg_strength', 'number_number'),
#  ('pos_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_strength', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('pos_strength', 'num_slang', 'avg_word_len', 'number_number'),
#  ('pos_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_strength', 'num_slang', 'neg', 'number_number'),
#  ('pos_strength', 'num_slang', 'neg_strength', 'number_number'),
#  ('pos_strength', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_strength', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_strength', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('pos_strength', 'neg', 'neg_strength', 'number_number'),
#  ('pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg_strength', 'pos', 'num_slang', 'neg'),
#  ('pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg_strength', 'pos', 'num_slang', 'number_number'),
#  ('pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg'),
#  ('pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg_strength', 'pos', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg_strength', 'pos', 'neg', 'neg_strength'),
#  ('pos_vs_neg_strength', 'pos', 'neg', 'number_number'),
#  ('pos_vs_neg_strength', 'pos', 'neg_strength', 'number_number'),
#  ('pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_vs_neg_strength', 'num_slang', 'neg', 'number_number'),
#  ('pos_vs_neg_strength', 'num_slang', 'neg_strength', 'number_number'),
#  ('pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_vs_neg_strength', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_vs_neg_strength', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('pos_vs_neg_strength', 'neg', 'neg_strength', 'number_number'),
#  ('pos', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('pos', 'num_slang', 'avg_word_len', 'number_number'),
#  ('pos', 'num_slang', 'neg', 'neg_strength'),
#  ('pos', 'num_slang', 'neg', 'number_number'),
#  ('pos', 'num_slang', 'neg_strength', 'number_number'),
#  ('pos', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos', 'avg_word_len', 'neg', 'number_number'),
#  ('pos', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('pos', 'neg', 'neg_strength', 'number_number'),
#  ('num_slang', 'avg_word_len', 'neg', 'neg_strength'),
#  ('num_slang', 'avg_word_len', 'neg', 'number_number'),
#  ('num_slang', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('num_slang', 'neg', 'neg_strength', 'number_number'),
#  ('avg_word_len', 'neg', 'neg_strength', 'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'num_slang'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'neg'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'neg'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang', 'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'avg_word_len', 'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'avg_word_len',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'neg', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_vs_neg', 'neg', 'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg',
#   'neg_strength',
#   'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'pos'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos_strength', 'pos', 'num_slang'),
#  ('exclamation', 'question_mark', 'pos_strength', 'pos', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_strength', 'pos', 'neg'),
#  ('exclamation', 'question_mark', 'pos_strength', 'pos', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_strength', 'pos', 'number_number'),
#  ('exclamation', 'question_mark', 'pos_strength', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_strength', 'num_slang', 'neg'),
#  ('exclamation', 'question_mark', 'pos_strength', 'num_slang', 'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'num_slang',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos_strength', 'avg_word_len', 'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos_strength', 'neg', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos_strength', 'neg', 'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_strength',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'pos',
#   'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'pos',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'pos',
#   'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'neg',
#   'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'neg',
#   'number_number'),
#  ('exclamation',
#   'question_mark',
#   'pos_vs_neg_strength',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'question_mark', 'pos', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'question_mark', 'pos', 'num_slang', 'neg'),
#  ('exclamation', 'question_mark', 'pos', 'num_slang', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos', 'num_slang', 'number_number'),
#  ('exclamation', 'question_mark', 'pos', 'avg_word_len', 'neg'),
#  ('exclamation', 'question_mark', 'pos', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos', 'avg_word_len', 'number_number'),
#  ('exclamation', 'question_mark', 'pos', 'neg', 'neg_strength'),
#  ('exclamation', 'question_mark', 'pos', 'neg', 'number_number'),
#  ('exclamation', 'question_mark', 'pos', 'neg_strength', 'number_number'),
#  ('exclamation', 'question_mark', 'num_slang', 'avg_word_len', 'neg'),
#  ('exclamation', 'question_mark', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('exclamation',
#   'question_mark',
#   'num_slang',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'question_mark', 'num_slang', 'neg', 'neg_strength'),
#  ('exclamation', 'question_mark', 'num_slang', 'neg', 'number_number'),
#  ('exclamation',
#   'question_mark',
#   'num_slang',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'question_mark', 'avg_word_len', 'neg', 'neg_strength'),
#  ('exclamation', 'question_mark', 'avg_word_len', 'neg', 'number_number'),
#  ('exclamation',
#   'question_mark',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'question_mark', 'neg', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg_strength'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'num_slang', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg_strength'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_strength',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_strength', 'neg', 'number_number'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_strength',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'number_number'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'number_number'),
#  ('exclamation',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'num_slang', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'neg', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'pos', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'neg', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'num_slang', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg', 'avg_word_len', 'neg', 'number_number'),
#  ('exclamation',
#   'pos_vs_neg',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg', 'neg', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'pos',
#   'number_number'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'number_number'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg',
#   'number_number'),
#  ('exclamation',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos_strength', 'pos', 'num_slang', 'neg'),
#  ('exclamation', 'pos_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'pos', 'num_slang', 'number_number'),
#  ('exclamation', 'pos_strength', 'pos', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_strength', 'pos', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'pos', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos_strength', 'pos', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'pos', 'neg', 'number_number'),
#  ('exclamation', 'pos_strength', 'pos', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'num_slang', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'num_slang', 'neg', 'number_number'),
#  ('exclamation', 'pos_strength', 'num_slang', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_strength', 'avg_word_len', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_strength', 'avg_word_len', 'neg', 'number_number'),
#  ('exclamation',
#   'pos_strength',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_strength', 'neg', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'num_slang', 'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'pos',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'pos', 'neg', 'number_number'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'pos',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'neg_strength'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('exclamation', 'pos_vs_neg_strength', 'num_slang', 'neg', 'number_number'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg',
#   'number_number'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('exclamation',
#   'pos_vs_neg_strength',
#   'neg',
#   'neg_strength',
#   'number_number'),
#  ('exclamation', 'pos', 'num_slang', 'avg_word_len', 'neg'),
#  ('exclamation', 'pos', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('exclamation', 'pos', 'num_slang', 'avg_word_len', 'number_number'),
#  ('exclamation', 'pos', 'num_slang', 'neg', 'neg_strength'),
#  ('exclamation', 'pos', 'num_slang', 'neg', 'number_number'),
#  ('exclamation', 'pos', 'num_slang', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos', 'avg_word_len', 'neg', 'neg_strength'),
#  ('exclamation', 'pos', 'avg_word_len', 'neg', 'number_number'),
#  ('exclamation', 'pos', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('exclamation', 'pos', 'neg', 'neg_strength', 'number_number'),
#  ('exclamation', 'num_slang', 'avg_word_len', 'neg', 'neg_strength'),
#  ('exclamation', 'num_slang', 'avg_word_len', 'neg', 'number_number'),
#  ('exclamation', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('exclamation', 'num_slang', 'neg', 'neg_strength', 'number_number'),
#  ('exclamation', 'avg_word_len', 'neg', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg_strength'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('question_mark',
# ...
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'pos',
#   'number_number'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'neg',
#   'number_number'),
#  ('question_mark',
#   'pos_vs_neg',
#   'pos_vs_neg_strength',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'neg', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'pos', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'neg', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'num_slang', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg', 'avg_word_len', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg', 'avg_word_len', 'neg', 'number_number'),
#  ('question_mark',
#   'pos_vs_neg',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg', 'neg', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'pos',
#   'avg_word_len'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'pos',
#   'neg_strength'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'pos',
#   'number_number'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len'),
#  ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'number_number'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'number_number'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg',
#   'neg_strength'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg',
#   'number_number'),
#  ('question_mark',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'pos_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos_strength', 'pos', 'num_slang', 'neg'),
#  ('question_mark', 'pos_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'pos', 'num_slang', 'number_number'),
#  ('question_mark', 'pos_strength', 'pos', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos_strength', 'pos', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'pos', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos_strength', 'pos', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'pos', 'neg', 'number_number'),
#  ('question_mark', 'pos_strength', 'pos', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('question_mark',
#   'pos_strength',
#   'num_slang',
#   'avg_word_len',
#   'neg_strength'),
#  ('question_mark',
#   'pos_strength',
#   'num_slang',
#   'avg_word_len',
#   'number_number'),
#  ('question_mark', 'pos_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'num_slang', 'neg', 'number_number'),
#  ('question_mark',
#   'pos_strength',
#   'num_slang',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'pos_strength', 'avg_word_len', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_strength', 'avg_word_len', 'neg', 'number_number'),
#  ('question_mark',
#   'pos_strength',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'pos_strength', 'neg', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'pos',
#   'avg_word_len',
#   'neg_strength'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'pos',
#   'avg_word_len',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'pos', 'neg', 'number_number'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'pos',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'neg_strength'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'number_number'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('question_mark', 'pos_vs_neg_strength', 'num_slang', 'neg', 'number_number'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength',
#   'number_number'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg',
#   'neg_strength'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg',
#   'number_number'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('question_mark',
#   'pos_vs_neg_strength',
#   'neg',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'pos', 'num_slang', 'avg_word_len', 'neg'),
#  ('question_mark', 'pos', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('question_mark', 'pos', 'num_slang', 'avg_word_len', 'number_number'),
#  ('question_mark', 'pos', 'num_slang', 'neg', 'neg_strength'),
#  ('question_mark', 'pos', 'num_slang', 'neg', 'number_number'),
#  ('question_mark', 'pos', 'num_slang', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos', 'avg_word_len', 'neg', 'neg_strength'),
#  ('question_mark', 'pos', 'avg_word_len', 'neg', 'number_number'),
#  ('question_mark', 'pos', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('question_mark', 'pos', 'neg', 'neg_strength', 'number_number'),
#  ('question_mark', 'num_slang', 'avg_word_len', 'neg', 'neg_strength'),
#  ('question_mark', 'num_slang', 'avg_word_len', 'neg', 'number_number'),
#  ('question_mark',
#   'num_slang',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('question_mark', 'num_slang', 'neg', 'neg_strength', 'number_number'),
#  ('question_mark', 'avg_word_len', 'neg', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'number_number'),
#  ('pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg'),
#  ('pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength'),
#  ('pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg'),
#  ('pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength'),
#  ('pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'neg', 'number_number'),
#  ('pos_vs_neg',
#   'pos_strength',
#   'pos_vs_neg_strength',
#   'neg_strength',
#   'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'pos', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'num_slang', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_strength', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_vs_neg',
#   'pos_strength',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('pos_vs_neg', 'pos_strength', 'neg', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'neg_strength'),
#  ('pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'neg', 'number_number'),
#  ('pos_vs_neg',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength',
#   'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_vs_neg',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('pos_vs_neg', 'pos_vs_neg_strength', 'neg', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'avg_word_len', 'number_number'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos', 'num_slang', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'pos', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_vs_neg', 'pos', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'pos', 'neg', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'num_slang', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_vs_neg', 'num_slang', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_vs_neg', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'num_slang', 'neg', 'neg_strength', 'number_number'),
#  ('pos_vs_neg', 'avg_word_len', 'neg', 'neg_strength', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'pos',
#   'avg_word_len',
#   'neg_strength'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'pos',
#   'avg_word_len',
#   'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'pos', 'neg', 'number_number'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'pos',
#   'neg_strength',
#   'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'neg_strength'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'avg_word_len',
#   'number_number'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg', 'number_number'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'num_slang',
#   'neg_strength',
#   'number_number'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg',
#   'neg_strength'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg',
#   'number_number'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ('pos_strength',
#   'pos_vs_neg_strength',
#   'neg',
#   'neg_strength',
#   'number_number'),
#  ('pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg'),
#  ('pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength'),
#  ('pos_strength', 'pos', 'num_slang', 'avg_word_len', 'number_number'),
#  ('pos_strength', 'pos', 'num_slang', 'neg', 'neg_strength'),
#  ('pos_strength', 'pos', 'num_slang', 'neg', 'number_number'),
#  ('pos_strength', 'pos', 'num_slang', 'neg_strength', 'number_number'),
#  ('pos_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_strength', 'pos', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_strength', 'pos', 'avg_word_len', 'neg_strength', 'number_number'),
#  ('pos_strength', 'pos', 'neg', 'neg_strength', 'number_number'),
#  ('pos_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength'),
#  ('pos_strength', 'num_slang', 'avg_word_len', 'neg', 'number_number'),
#  ('pos_strength',
#   'num_slang',
#   'avg_word_len',
#   'neg_strength',
#   'number_number'),
#  ...]

# %% [markdown]
# ### SVM

# %%
from sklearn import svm
Cs = np.logspace(-1, 2, 10)
gammas = [0.001, 0.0001]
svc = svm.SVC(probability=True)
#clf = grid_search(svc,data['feature'],data['sentiment'],dict(C=Cs))

# %%
clf = grid_search(svc,data['feature'],data['sentiment'],dict(C=Cs), cv=5, feature_scaled=True,output=False)
# Out:
# 0.772189349112

# %%
for subset in subsets:
    subset_feature = []
    for feature in data['feature']:
        subset_feature.append({k:feature[k] for k in subset})
    subset_feature = np.array(subset_feature)
    print(subset)
    grid_search(svc,subset_feature,data['sentiment'],dict(C=Cs))
    grid_search(svc,subset_feature,data['sentiment'],dict(C=Cs),cv=5)
    grid_search(svc,subset_feature,data['sentiment'],dict(C=Cs),feature_scaled=True)
    grid_search(svc,subset_feature,data['sentiment'],dict(C=Cs),cv=5,feature_scaled=True)
# Out:
# ('exclamation',)
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# ('question_mark',)
# 0.674556213018
# 0.674556213018
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.674556213018
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.674556213018
# ('pos_vs_neg',)
# 0.730769230769
# 0.730769230769
# 0.730769230769
# 0.736686390533
# ('pos_strength',)
# 0.650887573964
# 0.633136094675
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# ('pos_vs_neg_strength',)
# 0.751479289941
# 0.751479289941
# 0.718934911243
# 0.727810650888
# ('pos',)
# 0.621301775148
# 0.621301775148
# 0.647928994083
# 0.650887573964
# ('num_slang',)
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.630177514793
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# ('avg_word_len',)
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('neg',)
# 0.698224852071
# 0.695266272189
# 0.698224852071
# 0.710059171598
# ('neg_strength',)
# 0.671597633136
# 0.656804733728
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# ('number_number',)
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.62426035503
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# ('exclamation', 'question_mark')
# 0.686390532544
# 0.683431952663
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.692307692308
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.692307692308
# ('exclamation', 'pos_vs_neg')
# 0.739644970414
# 0.733727810651
# 0.733727810651
# 0.727810650888
# ('exclamation', 'pos_strength')
# 0.636094674556
# 0.644970414201
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.633136094675
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.627218934911
# ('exclamation', 'pos_vs_neg_strength')
# 0.733727810651
# 0.739644970414
# 0.721893491124
# 0.727810650888
# ('exclamation', 'pos')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('exclamation', 'num_slang')
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# ('exclamation', 'avg_word_len')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('exclamation', 'neg')
# 0.689349112426
# 0.680473372781
# 0.707100591716
# 0.718934911243
# ('exclamation', 'neg_strength')
# 0.662721893491
# 0.656804733728
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.695266272189
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.704142011834
# ('exclamation', 'number_number')
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.627218934911
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.630177514793
# ('question_mark', 'pos_vs_neg')
# 0.751479289941
# 0.739644970414
# 0.745562130178
# 0.736686390533
# ('question_mark', 'pos_strength')
# 0.662721893491
# 0.633136094675
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.683431952663
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.683431952663
# ('question_mark', 'pos_vs_neg_strength')
# 0.766272189349
# 0.760355029586
# 0.713017751479
# 0.721893491124
# ('question_mark', 'pos')
# 0.677514792899
# 0.674556213018
# 0.674556213018
# 0.677514792899
# ('question_mark', 'num_slang')
# 0.686390532544
# 0.665680473373
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.692307692308
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.668639053254
# ('question_mark', 'avg_word_len')
# 0.677514792899
# 0.677514792899
# 0.686390532544
# 0.677514792899
# ('question_mark', 'neg')
# 0.692307692308
# 0.692307692308
# 0.745562130178
# 0.742603550296
# ('question_mark', 'neg_strength')
# 0.701183431953
# 0.695266272189
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.713017751479
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.701183431953
# ('question_mark', 'number_number')
# 0.668639053254
# 0.656804733728
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# ('pos_vs_neg', 'pos_strength')
# 0.727810650888
# 0.724852071006
# 0.724852071006
# 0.724852071006
# ('pos_vs_neg', 'pos_vs_neg_strength')
# 0.745562130178
# 0.745562130178
# 0.736686390533
# 0.727810650888
# ('pos_vs_neg', 'pos')
# 0.730769230769
# 0.733727810651
# 0.718934911243
# 0.730769230769
# ('pos_vs_neg', 'num_slang')
# 0.730769230769
# 0.733727810651
# 0.730769230769
# 0.730769230769
# ('pos_vs_neg', 'avg_word_len')
# 0.736686390533
# 0.733727810651
# 0.715976331361
# 0.724852071006
# ('pos_vs_neg', 'neg')
# 0.730769230769
# 0.733727810651
# 0.718934911243
# 0.730769230769
# ('pos_vs_neg', 'neg_strength')
# 0.692307692308
# 0.707100591716
# 0.742603550296
# 0.739644970414
# ('pos_vs_neg', 'number_number')
# 0.650887573964
# 0.621301775148
# 0.724852071006
# 0.724852071006
# ('pos_strength', 'pos_vs_neg_strength')
# 0.727810650888
# 0.739644970414
# 0.742603550296
# 0.745562130178
# ('pos_strength', 'pos')
# 0.647928994083
# 0.62426035503
# 0.633136094675
# 0.644970414201
# ('pos_strength', 'num_slang')
# 0.644970414201
# 0.630177514793
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# ('pos_strength', 'avg_word_len')
# 0.647928994083
# 0.636094674556
# 0.621301775148
# 0.621301775148
# ('pos_strength', 'neg')
# 0.647928994083
# 0.62426035503
# 0.727810650888
# 0.733727810651
# ('pos_strength', 'neg_strength')
# 0.683431952663
# 0.683431952663
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.766272189349
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.760355029586
# ('pos_strength', 'number_number')
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.627218934911
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.627218934911
# ('pos_vs_neg_strength', 'pos')
# 0.727810650888
# 0.721893491124
# 0.751479289941
# 0.733727810651
# ('pos_vs_neg_strength', 'num_slang')
# 0.713017751479
# 0.715976331361
# 0.713017751479
# 0.727810650888
# ('pos_vs_neg_strength', 'avg_word_len')
# 0.727810650888
# 0.733727810651
# 0.710059171598
# 0.736686390533
# ('pos_vs_neg_strength', 'neg')
# 0.775147928994
# 0.778106508876
# 0.760355029586
# 0.763313609467
# ('pos_vs_neg_strength', 'neg_strength')
# 0.686390532544
# 0.686390532544
# 0.754437869822
# 0.760355029586
# ('pos_vs_neg_strength', 'number_number')
# 0.665680473373
# 0.633136094675
# 0.710059171598
# 0.713017751479
# ('pos', 'num_slang')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('pos', 'avg_word_len')
# 0.621301775148
# 0.621301775148
# 0.64201183432
# 0.656804733728
# ('pos', 'neg')
# 0.707100591716
# 0.707100591716
# 0.715976331361
# 0.736686390533
# ('pos', 'neg_strength')
# 0.680473372781
# 0.665680473373
# 0.698224852071
# 0.713017751479
# ('pos', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.627218934911
# 0.621301775148
# ('num_slang', 'avg_word_len')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('num_slang', 'neg')
# 0.686390532544
# 0.674556213018
# 0.686390532544
# 0.695266272189
# ('num_slang', 'neg_strength')
# 0.683431952663
# 0.662721893491
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.677514792899
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.677514792899
# ('num_slang', 'number_number')
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.636094674556
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.639053254438
# ('avg_word_len', 'neg')
# 0.695266272189
# 0.695266272189
# 0.698224852071
# 0.704142011834
# ('avg_word_len', 'neg_strength')
# 0.662721893491
# 0.656804733728
# 0.656804733728
# 0.665680473373
# ('avg_word_len', 'number_number')
# 0.627218934911
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('neg', 'neg_strength')
# 0.680473372781
# 0.665680473373
# 0.727810650888
# 0.721893491124
# ('neg', 'number_number')
# 0.639053254438
# 0.621301775148
# 0.701183431953
# 0.704142011834
# ('neg_strength', 'number_number')
# 0.639053254438
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.680473372781
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.680473372781
# ('exclamation', 'question_mark', 'pos_vs_neg')
# 0.742603550296
# 0.736686390533
# 0.736686390533
# 0.736686390533
# ('exclamation', 'question_mark', 'pos_strength')
# 0.647928994083
# 0.639053254438
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# ('exclamation', 'question_mark', 'pos_vs_neg_strength')
# 0.718934911243
# 0.715976331361
# 0.704142011834
# 0.695266272189
# ('exclamation', 'question_mark', 'pos')
# 0.689349112426
# 0.689349112426
# 0.689349112426
# 0.680473372781
# ('exclamation', 'question_mark', 'num_slang')
# 0.686390532544
# 0.683431952663
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.683431952663
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.671597633136
# ('exclamation', 'question_mark', 'avg_word_len')
# 0.689349112426
# 0.689349112426
# 0.677514792899
# 0.680473372781
# ('exclamation', 'question_mark', 'neg')
# 0.701183431953
# 0.689349112426
# 0.730769230769
# 0.724852071006
# ('exclamation', 'question_mark', 'neg_strength')
# 0.713017751479
# 0.701183431953
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.730769230769
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.724852071006
# ('exclamation', 'question_mark', 'number_number')
# 0.644970414201
# 0.656804733728
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.698224852071
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.698224852071
# ('exclamation', 'pos_vs_neg', 'pos_strength')
# 0.718934911243
# 0.736686390533
# 0.713017751479
# 0.730769230769
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength')
# 0.748520710059
# 0.748520710059
# 0.724852071006
# 0.715976331361
# ('exclamation', 'pos_vs_neg', 'pos')
# 0.733727810651
# 0.730769230769
# 0.727810650888
# 0.724852071006
# ('exclamation', 'pos_vs_neg', 'num_slang')
# 0.724852071006
# 0.721893491124
# 0.724852071006
# 0.721893491124
# ('exclamation', 'pos_vs_neg', 'avg_word_len')
# 0.721893491124
# 0.724852071006
# 0.707100591716
# 0.710059171598
# ('exclamation', 'pos_vs_neg', 'neg')
# 0.733727810651
# 0.730769230769
# 0.707100591716
# 0.730769230769
# ('exclamation', 'pos_vs_neg', 'neg_strength')
# 0.692307692308
# 0.713017751479
# 0.724852071006
# 0.733727810651
# ('exclamation', 'pos_vs_neg', 'number_number')
# 0.653846153846
# 0.621301775148
# 0.718934911243
# 0.713017751479
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength')
# 0.745562130178
# 0.757396449704
# 0.766272189349
# 0.778106508876
# ('exclamation', 'pos_strength', 'pos')
# 0.64201183432
# 0.64201183432
# 0.647928994083
# 0.650887573964
# ('exclamation', 'pos_strength', 'num_slang')
# 0.630177514793
# 0.639053254438
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.621301775148
# ('exclamation', 'pos_strength', 'avg_word_len')
# 0.636094674556
# 0.644970414201
# 0.621301775148
# 0.621301775148
# ('exclamation', 'pos_strength', 'neg')
# 0.64201183432
# 0.64201183432
# 0.733727810651
# 0.742603550296
# ('exclamation', 'pos_strength', 'neg_strength')
# 0.692307692308
# 0.701183431953
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.754437869822
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.760355029586
# ('exclamation', 'pos_strength', 'number_number')
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.627218934911
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.627218934911
# ('exclamation', 'pos_vs_neg_strength', 'pos')
# 0.718934911243
# 0.721893491124
# 0.721893491124
# 0.710059171598
# ('exclamation', 'pos_vs_neg_strength', 'num_slang')
# 0.707100591716
# 0.715976331361
# 0.701183431953
# 0.707100591716
# ('exclamation', 'pos_vs_neg_strength', 'avg_word_len')
# 0.745562130178
# 0.754437869822
# 0.715976331361
# 0.727810650888
# ('exclamation', 'pos_vs_neg_strength', 'neg')
# 0.754437869822
# 0.757396449704
# 0.763313609467
# 0.760355029586
# ('exclamation', 'pos_vs_neg_strength', 'neg_strength')
# 0.698224852071
# 0.713017751479
# 0.748520710059
# 0.751479289941
# ('exclamation', 'pos_vs_neg_strength', 'number_number')
# 0.668639053254
# 0.674556213018
# 0.715976331361
# 0.710059171598
# ('exclamation', 'pos', 'num_slang')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('exclamation', 'pos', 'avg_word_len')
# 0.621301775148
# 0.621301775148
# 0.633136094675
# 0.636094674556
# ('exclamation', 'pos', 'neg')
# 0.689349112426
# 0.689349112426
# 0.721893491124
# 0.736686390533
# ('exclamation', 'pos', 'neg_strength')
# 0.677514792899
# 0.668639053254
# 0.704142011834
# 0.718934911243
# ('exclamation', 'pos', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.630177514793
# 0.636094674556
# ('exclamation', 'num_slang', 'avg_word_len')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('exclamation', 'num_slang', 'neg')
# 0.680473372781
# 0.677514792899
# 0.701183431953
# 0.701183431953
# ('exclamation', 'num_slang', 'neg_strength')
# 0.653846153846
# 0.653846153846
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.692307692308
# ('exclamation', 'num_slang', 'number_number')
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.62426035503
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.636094674556
# ('exclamation', 'avg_word_len', 'neg')
# 0.689349112426
# 0.671597633136
# 0.715976331361
# 0.715976331361
# ('exclamation', 'avg_word_len', 'neg_strength')
# 0.659763313609
# 0.665680473373
# 0.668639053254
# 0.683431952663
# ('exclamation', 'avg_word_len', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.627218934911
# ('exclamation', 'neg', 'neg_strength')
# 0.677514792899
# 0.668639053254
# 0.715976331361
# 0.721893491124
# ('exclamation', 'neg', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.707100591716
# 0.721893491124
# ('exclamation', 'neg_strength', 'number_number')
# 0.674556213018
# 0.683431952663
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.689349112426
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.701183431953
# ('question_mark', 'pos_vs_neg', 'pos_strength')
# 0.698224852071
# 0.692307692308
# 0.739644970414
# 0.742603550296
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength')
# 0.772189349112
# 0.757396449704
# 0.763313609467
# 0.748520710059
# ('question_mark', 'pos_vs_neg', 'pos')
# 0.748520710059
# 0.736686390533
# 0.754437869822
# 0.754437869822
# ('question_mark', 'pos_vs_neg', 'num_slang')
# 0.751479289941
# 0.739644970414
# 0.748520710059
# 0.724852071006
# ('question_mark', 'pos_vs_neg', 'avg_word_len')
# 0.739644970414
# 0.730769230769
# 0.730769230769
# 0.736686390533
# ('question_mark', 'pos_vs_neg', 'neg')
# 0.745562130178
# 0.736686390533
# 0.742603550296
# 0.739644970414
# ('question_mark', 'pos_vs_neg', 'neg_strength')
# 0.748520710059
# 0.751479289941
# 0.766272189349
# 0.769230769231
# ('question_mark', 'pos_vs_neg', 'number_number')
# 0.656804733728
# 0.644970414201
# 0.733727810651
# 0.739644970414
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength')
# 0.748520710059
# 0.733727810651
# 0.736686390533
# 0.757396449704
# ('question_mark', 'pos_strength', 'pos')
# 0.662721893491
# 0.630177514793
# 0.680473372781
# 0.677514792899
# ('question_mark', 'pos_strength', 'num_slang')
# 0.683431952663
# 0.656804733728
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.680473372781
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.674556213018
# ('question_mark', 'pos_strength', 'avg_word_len')
# 0.710059171598
# 0.683431952663
# 0.689349112426
# 0.698224852071
# ('question_mark', 'pos_strength', 'neg')
# 0.656804733728
# 0.636094674556
# 0.727810650888
# 0.721893491124
# ('question_mark', 'pos_strength', 'neg_strength')
# 0.707100591716
# 0.677514792899
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.784023668639
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.781065088757
# ('question_mark', 'pos_strength', 'number_number')
# 0.627218934911
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.665680473373
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.671597633136
# ('question_mark', 'pos_vs_neg_strength', 'pos')
# 0.733727810651
# 0.742603550296
# 0.781065088757
# 0.778106508876
# ('question_mark', 'pos_vs_neg_strength', 'num_slang')
# 0.736686390533
# 0.742603550296
# 0.710059171598
# 0.695266272189
# ('question_mark', 'pos_vs_neg_strength', 'avg_word_len')
# 0.742603550296
# 0.754437869822
# 0.698224852071
# 0.721893491124
# ('question_mark', 'pos_vs_neg_strength', 'neg')
# 0.766272189349
# 0.778106508876
# 0.789940828402
# 0.781065088757
# ('question_mark', 'pos_vs_neg_strength', 'neg_strength')
# 0.724852071006
# 0.707100591716
# 0.789940828402
# 0.789940828402
# ('question_mark', 'pos_vs_neg_strength', 'number_number')
# 0.671597633136
# 0.665680473373
# 0.713017751479
# 0.710059171598
# ('question_mark', 'pos', 'num_slang')
# 0.683431952663
# 0.665680473373
# 0.671597633136
# 0.656804733728
# ('question_mark', 'pos', 'avg_word_len')
# 0.677514792899
# 0.674556213018
# 0.665680473373
# 0.668639053254
# ('question_mark', 'pos', 'neg')
# 0.724852071006
# 0.710059171598
# 0.754437869822
# 0.742603550296
# ('question_mark', 'pos', 'neg_strength')
# 0.707100591716
# 0.695266272189
# 0.772189349112
# 0.769230769231
# ('question_mark', 'pos', 'number_number')
# 0.665680473373
# 0.659763313609
# 0.686390532544
# 0.677514792899
# ('question_mark', 'num_slang', 'avg_word_len')
# 0.695266272189
# 0.668639053254
# 0.671597633136
# 0.668639053254
# ('question_mark', 'num_slang', 'neg')
# 0.683431952663
# 0.668639053254
# 0.736686390533
# 0.739644970414
# ('question_mark', 'num_slang', 'neg_strength')
# 0.713017751479
# 0.692307692308
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.724852071006
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.707100591716
# ('question_mark', 'num_slang', 'number_number')
# 0.656804733728
# 0.647928994083
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.701183431953
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.689349112426
# ('question_mark', 'avg_word_len', 'neg')
# 0.698224852071
# 0.704142011834
# 0.736686390533
# 0.742603550296
# ('question_mark', 'avg_word_len', 'neg_strength')
# 0.710059171598
# 0.689349112426
# 0.718934911243
# 0.715976331361
# ('question_mark', 'avg_word_len', 'number_number')
# 0.665680473373
# 0.653846153846
# 0.686390532544
# 0.683431952663
# ('question_mark', 'neg', 'neg_strength')
# 0.707100591716
# 0.695266272189
# 0.757396449704
# 0.745562130178
# ('question_mark', 'neg', 'number_number')
# 0.662721893491
# 0.662721893491
# 0.736686390533
# 0.745562130178
# ('question_mark', 'neg_strength', 'number_number')
# 0.647928994083
# 0.647928994083
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.704142011834
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.692307692308
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength')
# 0.760355029586
# 0.766272189349
# 0.754437869822
# 0.763313609467
# ('pos_vs_neg', 'pos_strength', 'pos')
# 0.724852071006
# 0.724852071006
# 0.742603550296
# 0.754437869822
# ('pos_vs_neg', 'pos_strength', 'num_slang')
# 0.707100591716
# 0.701183431953
# 0.713017751479
# 0.721893491124
# ('pos_vs_neg', 'pos_strength', 'avg_word_len')
# 0.730769230769
# 0.730769230769
# 0.733727810651
# 0.730769230769
# ('pos_vs_neg', 'pos_strength', 'neg')
# 0.718934911243
# 0.724852071006
# 0.736686390533
# 0.751479289941
# ('pos_vs_neg', 'pos_strength', 'neg_strength')
# 0.707100591716
# 0.710059171598
# 0.763313609467
# 0.763313609467
# ('pos_vs_neg', 'pos_strength', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.710059171598
# 0.715976331361
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos')
# 0.742603550296
# 0.742603550296
# 0.766272189349
# 0.766272189349
# ('pos_vs_neg', 'pos_vs_neg_strength', 'num_slang')
# 0.736686390533
# 0.736686390533
# 0.718934911243
# 0.718934911243
# ('pos_vs_neg', 'pos_vs_neg_strength', 'avg_word_len')
# 0.742603550296
# 0.754437869822
# 0.739644970414
# 0.742603550296
# ('pos_vs_neg', 'pos_vs_neg_strength', 'neg')
# 0.739644970414
# 0.742603550296
# 0.757396449704
# 0.757396449704
# ('pos_vs_neg', 'pos_vs_neg_strength', 'neg_strength')
# 0.715976331361
# 0.718934911243
# 0.757396449704
# 0.745562130178
# ('pos_vs_neg', 'pos_vs_neg_strength', 'number_number')
# 0.692307692308
# 0.668639053254
# 0.724852071006
# 0.718934911243
# ('pos_vs_neg', 'pos', 'num_slang')
# 0.727810650888
# 0.730769230769
# 0.715976331361
# 0.704142011834
# ('pos_vs_neg', 'pos', 'avg_word_len')
# 0.730769230769
# 0.733727810651
# 0.721893491124
# 0.724852071006
# ('pos_vs_neg', 'pos', 'neg')
# 0.730769230769
# 0.733727810651
# 0.724852071006
# 0.730769230769
# ('pos_vs_neg', 'pos', 'neg_strength')
# 0.695266272189
# 0.715976331361
# 0.745562130178
# 0.742603550296
# ('pos_vs_neg', 'pos', 'number_number')
# 0.668639053254
# 0.64201183432
# 0.730769230769
# 0.730769230769
# ('pos_vs_neg', 'num_slang', 'avg_word_len')
# 0.730769230769
# 0.733727810651
# 0.713017751479
# 0.701183431953
# ('pos_vs_neg', 'num_slang', 'neg')
# 0.727810650888
# 0.727810650888
# 0.701183431953
# 0.707100591716
# ('pos_vs_neg', 'num_slang', 'neg_strength')
# 0.686390532544
# 0.692307692308
# 0.724852071006
# 0.727810650888
# ('pos_vs_neg', 'num_slang', 'number_number')
# 0.665680473373
# 0.627218934911
# 0.727810650888
# 0.724852071006
# ('pos_vs_neg', 'avg_word_len', 'neg')
# 0.730769230769
# 0.730769230769
# 0.698224852071
# 0.704142011834
# ('pos_vs_neg', 'avg_word_len', 'neg_strength')
# 0.695266272189
# 0.727810650888
# 0.733727810651
# 0.727810650888
# ('pos_vs_neg', 'avg_word_len', 'number_number')
# 0.683431952663
# 0.639053254438
# 0.701183431953
# 0.701183431953
# ('pos_vs_neg', 'neg', 'neg_strength')
# 0.695266272189
# 0.715976331361
# 0.748520710059
# 0.751479289941
# ('pos_vs_neg', 'neg', 'number_number')
# 0.668639053254
# 0.636094674556
# 0.713017751479
# 0.724852071006
# ('pos_vs_neg', 'neg_strength', 'number_number')
# 0.692307692308
# 0.677514792899
# 0.721893491124
# 0.721893491124
# ('pos_strength', 'pos_vs_neg_strength', 'pos')
# 0.730769230769
# 0.748520710059
# 0.748520710059
# 0.754437869822
# ('pos_strength', 'pos_vs_neg_strength', 'num_slang')
# 0.733727810651
# 0.724852071006
# 0.718934911243
# 0.710059171598
# ('pos_strength', 'pos_vs_neg_strength', 'avg_word_len')
# 0.748520710059
# 0.748520710059
# 0.733727810651
# 0.733727810651
# ('pos_strength', 'pos_vs_neg_strength', 'neg')
# 0.730769230769
# 0.748520710059
# 0.769230769231
# 0.772189349112
# ('pos_strength', 'pos_vs_neg_strength', 'neg_strength')
# 0.701183431953
# 0.701183431953
# 0.760355029586
# 0.766272189349
# ('pos_strength', 'pos_vs_neg_strength', 'number_number')
# 0.662721893491
# 0.639053254438
# 0.713017751479
# 0.701183431953
# ('pos_strength', 'pos', 'num_slang')
# 0.644970414201
# 0.62426035503
# 0.639053254438
# 0.64201183432
# ('pos_strength', 'pos', 'avg_word_len')
# 0.647928994083
# 0.630177514793
# 0.644970414201
# 0.647928994083
# ('pos_strength', 'pos', 'neg')
# 0.662721893491
# 0.627218934911
# 0.748520710059
# 0.760355029586
# ('pos_strength', 'pos', 'neg_strength')
# 0.701183431953
# 0.704142011834
# 0.772189349112
# 0.769230769231
# ('pos_strength', 'pos', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.62426035503
# ('pos_strength', 'num_slang', 'avg_word_len')
# 0.656804733728
# 0.647928994083
# 0.621301775148
# 0.621301775148
# ('pos_strength', 'num_slang', 'neg')
# 0.644970414201
# 0.62426035503
# 0.713017751479
# 0.715976331361
# ('pos_strength', 'num_slang', 'neg_strength')
# 0.695266272189
# 0.695266272189
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.754437869822
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.757396449704
# ('pos_strength', 'num_slang', 'number_number')
# 0.621301775148
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.633136094675
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.62426035503
# ('pos_strength', 'avg_word_len', 'neg')
# 0.647928994083
# 0.630177514793
# 0.715976331361
# 0.724852071006
# ('pos_strength', 'avg_word_len', 'neg_strength')
# 0.698224852071
# 0.701183431953
# 0.760355029586
# 0.760355029586
# ('pos_strength', 'avg_word_len', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('pos_strength', 'neg', 'neg_strength')
# 0.701183431953
# 0.704142011834
# 0.786982248521
# 0.781065088757
# ('pos_strength', 'neg', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.710059171598
# 0.715976331361
# ('pos_strength', 'neg_strength', 'number_number')
# 0.653846153846
# 0.627218934911
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.748520710059
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.748520710059
# ('pos_vs_neg_strength', 'pos', 'num_slang')
# 0.715976331361
# 0.721893491124
# 0.727810650888
# 0.724852071006
# ('pos_vs_neg_strength', 'pos', 'avg_word_len')
# 0.727810650888
# 0.730769230769
# 0.727810650888
# 0.736686390533
# ('pos_vs_neg_strength', 'pos', 'neg')
# 0.763313609467
# 0.769230769231
# 0.748520710059
# 0.769230769231
# ('pos_vs_neg_strength', 'pos', 'neg_strength')
# 0.701183431953
# 0.698224852071
# 0.757396449704
# 0.778106508876
# ('pos_vs_neg_strength', 'pos', 'number_number')
# 0.668639053254
# 0.633136094675
# 0.736686390533
# 0.715976331361
# ('pos_vs_neg_strength', 'num_slang', 'avg_word_len')
# 0.721893491124
# 0.736686390533
# 0.721893491124
# 0.721893491124
# ('pos_vs_neg_strength', 'num_slang', 'neg')
# 0.757396449704
# 0.754437869822
# 0.739644970414
# 0.733727810651
# ('pos_vs_neg_strength', 'num_slang', 'neg_strength')
# 0.692307692308
# 0.674556213018
# 0.730769230769
# 0.727810650888
# ('pos_vs_neg_strength', 'num_slang', 'number_number')
# 0.695266272189
# 0.668639053254
# 0.695266272189
# 0.695266272189
# ('pos_vs_neg_strength', 'avg_word_len', 'neg')
# 0.739644970414
# 0.745562130178
# 0.760355029586
# 0.760355029586
# ('pos_vs_neg_strength', 'avg_word_len', 'neg_strength')
# 0.701183431953
# 0.698224852071
# 0.754437869822
# 0.748520710059
# ('pos_vs_neg_strength', 'avg_word_len', 'number_number')
# 0.680473372781
# 0.656804733728
# 0.701183431953
# 0.713017751479
# ('pos_vs_neg_strength', 'neg', 'neg_strength')
# 0.701183431953
# 0.698224852071
# 0.772189349112
# 0.763313609467
# ('pos_vs_neg_strength', 'neg', 'number_number')
# 0.665680473373
# 0.633136094675
# 0.742603550296
# 0.751479289941
# ('pos_vs_neg_strength', 'neg_strength', 'number_number')
# 0.659763313609
# 0.656804733728
# 0.736686390533
# 0.748520710059
# ('pos', 'num_slang', 'avg_word_len')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('pos', 'num_slang', 'neg')
# 0.704142011834
# 0.701183431953
# 0.715976331361
# 0.713017751479
# ('pos', 'num_slang', 'neg_strength')
# 0.686390532544
# 0.686390532544
# 0.695266272189
# 0.695266272189
# ('pos', 'num_slang', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('pos', 'avg_word_len', 'neg')
# 0.713017751479
# 0.713017751479
# 0.707100591716
# 0.727810650888
# ('pos', 'avg_word_len', 'neg_strength')
# 0.674556213018
# 0.662721893491
# 0.698224852071
# 0.704142011834
# ('pos', 'avg_word_len', 'number_number')
# 0.630177514793
# 0.621301775148
# 0.621301775148
# 0.621301775148
# ('pos', 'neg', 'neg_strength')
# 0.680473372781
# 0.686390532544
# 0.739644970414
# 0.739644970414
# ('pos', 'neg', 'number_number')
# 0.64201183432
# 0.633136094675
# 0.718934911243
# 0.736686390533
# ('pos', 'neg_strength', 'number_number')
# 0.668639053254
# 0.64201183432
# 0.692307692308
# 0.689349112426
# ('num_slang', 'avg_word_len', 'neg')
# 0.689349112426
# 0.662721893491
# 0.707100591716
# 0.713017751479
# ('num_slang', 'avg_word_len', 'neg_strength')
# 0.689349112426
# 0.674556213018
# 0.650887573964
# 0.653846153846
# ('num_slang', 'avg_word_len', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.630177514793
# 0.633136094675
# ('num_slang', 'neg', 'neg_strength')
# 0.686390532544
# 0.686390532544
# 0.707100591716
# 0.689349112426
# ('num_slang', 'neg', 'number_number')
# 0.621301775148
# 0.621301775148
# 0.704142011834
# 0.704142011834
# ('num_slang', 'neg_strength', 'number_number')
# 0.639053254438
# 0.639053254438
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.674556213018
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.680473372781
# ('avg_word_len', 'neg', 'neg_strength')
# 0.674556213018
# 0.665680473373
# 0.724852071006
# 0.730769230769
# ('avg_word_len', 'neg', 'number_number')
# 0.647928994083
# 0.621301775148
# 0.701183431953
# 0.713017751479
# ('avg_word_len', 'neg_strength', 'number_number')
# 0.650887573964
# 0.630177514793
# 0.653846153846
# 0.653846153846
# ('neg', 'neg_strength', 'number_number')
# 0.668639053254
# 0.64201183432
# 0.707100591716
# 0.707100591716
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength')
# 0.704142011834
# 0.704142011834
# 0.730769230769
# 0.739644970414
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength')
# 0.742603550296
# 0.748520710059
# 0.754437869822
# 0.754437869822
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos')
# 0.745562130178
# 0.739644970414
# 0.742603550296
# 0.751479289941
# ('exclamation', 'question_mark', 'pos_vs_neg', 'num_slang')
# 0.745562130178
# 0.742603550296
# 0.745562130178
# 0.733727810651
# ('exclamation', 'question_mark', 'pos_vs_neg', 'avg_word_len')
# 0.736686390533
# 0.745562130178
# 0.718934911243
# 0.713017751479
# ('exclamation', 'question_mark', 'pos_vs_neg', 'neg')
# 0.745562130178
# 0.739644970414
# 0.739644970414
# 0.736686390533
# ('exclamation', 'question_mark', 'pos_vs_neg', 'neg_strength')
# 0.736686390533
# 0.736686390533
# 0.772189349112
# 0.772189349112
# ('exclamation', 'question_mark', 'pos_vs_neg', 'number_number')
# 0.647928994083
# 0.650887573964
# 0.742603550296
# 0.730769230769
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength')
# 0.742603550296
# 0.739644970414
# 0.745562130178
# 0.748520710059
# ('exclamation', 'question_mark', 'pos_strength', 'pos')
# 0.653846153846
# 0.64201183432
# 0.674556213018
# 0.668639053254
# ('exclamation', 'question_mark', 'pos_strength', 'num_slang')
# 0.668639053254
# 0.653846153846
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.689349112426
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.674556213018
# ('exclamation', 'question_mark', 'pos_strength', 'avg_word_len')
# 0.695266272189
# 0.680473372781
# 0.680473372781
# 0.698224852071
# ('exclamation', 'question_mark', 'pos_strength', 'neg')
# 0.653846153846
# 0.64201183432
# 0.739644970414
# 0.751479289941
# ('exclamation', 'question_mark', 'pos_strength', 'neg_strength')
# 0.707100591716
# 0.698224852071
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.778106508876
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.804733727811
# ('exclamation', 'question_mark', 'pos_strength', 'number_number')
# 0.633136094675
# 0.621301775148
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.686390532544
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:420: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# 0.689349112426
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos')
# 0.707100591716
# 0.715976331361
# 0.751479289941
# 0.760355029586
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'num_slang')
# 0.718934911243
# 0.718934911243
# 0.695266272189
# 0.701183431953
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'avg_word_len')
# 0.733727810651
# 0.736686390533
# 0.704142011834
# 0.713017751479
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg')
# 0.748520710059
# 0.757396449704
# 0.784023668639
# 0.769230769231
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'neg_strength')
# 0.715976331361
# 0.718934911243
# 0.792899408284
# 0.798816568047
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'number_number')
# 0.683431952663
# 0.671597633136
# 0.698224852071
# 0.692307692308
# ('exclamation', 'question_mark', 'pos', 'num_slang')
# 0.683431952663
# 0.680473372781
# 0.674556213018
# 0.659763313609
# ('exclamation', 'question_mark', 'pos', 'avg_word_len')
# 0.692307692308
# 0.686390532544
# 0.668639053254
# 0.689349112426
# ('exclamation', 'question_mark', 'pos', 'neg')
# 0.715976331361
# 0.695266272189
# 0.739644970414
# 0.745562130178
# ('exclamation', 'question_mark', 'pos', 'neg_strength')
# 0.710059171598
# 0.713017751479
# 0.772189349112
# 0.778106508876
# ...
# 0.757396449704
# 0.739644970414
# 0.795857988166
# 0.795857988166
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.668639053254
# 0.680473372781
# 0.772189349112
# 0.778106508876
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.665680473373
# 0.656804733728
# 0.775147928994
# 0.775147928994
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.674556213018
# 0.650887573964
# 0.786982248521
# 0.792899408284
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.674556213018
# 0.662721893491
# 0.778106508876
# 0.784023668639
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.665680473373
# 0.656804733728
# 0.769230769231
# 0.772189349112
# ('question_mark', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.674556213018
# 0.668639053254
# 0.789940828402
# 0.789940828402
# ('question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.656804733728
# 0.671597633136
# 0.757396449704
# 0.775147928994
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.730769230769
# 0.739644970414
# 0.763313609467
# 0.784023668639
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.662721893491
# 0.650887573964
# 0.757396449704
# 0.772189349112
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.695266272189
# 0.674556213018
# 0.748520710059
# 0.760355029586
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.698224852071
# 0.683431952663
# 0.748520710059
# 0.754437869822
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.704142011834
# 0.686390532544
# 0.757396449704
# 0.769230769231
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.695266272189
# 0.674556213018
# 0.757396449704
# 0.760355029586
# ('pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.701183431953
# 0.686390532544
# 0.754437869822
# 0.772189349112
# ('pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.692307692308
# 0.686390532544
# 0.745562130178
# 0.760355029586
# ('pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.695266272189
# 0.668639053254
# 0.763313609467
# 0.772189349112
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg')
# 0.757396449704
# 0.739644970414
# 0.757396449704
# 0.775147928994
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength')
# 0.754437869822
# 0.748520710059
# 0.786982248521
# 0.801775147929
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'number_number')
# 0.680473372781
# 0.686390532544
# 0.760355029586
# 0.754437869822
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength')
# 0.754437869822
# 0.751479289941
# 0.775147928994
# 0.784023668639
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'number_number')
# 0.677514792899
# 0.677514792899
# 0.751479289941
# 0.775147928994
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg_strength', 'number_number')
# 0.689349112426
# 0.680473372781
# 0.772189349112
# 0.784023668639
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength')
# 0.745562130178
# 0.742603550296
# 0.778106508876
# 0.784023668639
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'number_number')
# 0.686390532544
# 0.689349112426
# 0.757396449704
# 0.775147928994
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg_strength', 'number_number')
# 0.698224852071
# 0.689349112426
# 0.781065088757
# 0.775147928994
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'neg', 'neg_strength', 'number_number')
# 0.698224852071
# 0.692307692308
# 0.769230769231
# 0.763313609467
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.754437869822
# 0.748520710059
# 0.772189349112
# 0.784023668639
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.680473372781
# 0.686390532544
# 0.748520710059
# 0.757396449704
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.692307692308
# 0.680473372781
# 0.772189349112
# 0.778106508876
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.689349112426
# 0.680473372781
# 0.757396449704
# 0.760355029586
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.698224852071
# 0.689349112426
# 0.754437869822
# 0.763313609467
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.760355029586
# 0.757396449704
# 0.778106508876
# 0.786982248521
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.639053254438
# 0.64201183432
# 0.766272189349
# 0.781065088757
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.692307692308
# 0.683431952663
# 0.778106508876
# 0.778106508876
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.695266272189
# 0.686390532544
# 0.754437869822
# 0.769230769231
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.704142011834
# 0.698224852071
# 0.760355029586
# 0.766272189349
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.692307692308
# 0.683431952663
# 0.760355029586
# 0.760355029586
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.748520710059
# 0.736686390533
# 0.772189349112
# 0.778106508876
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.698224852071
# 0.701183431953
# 0.748520710059
# 0.766272189349
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.683431952663
# 0.695266272189
# 0.751479289941
# 0.763313609467
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.686390532544
# 0.698224852071
# 0.745562130178
# 0.766272189349
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.695266272189
# 0.704142011834
# 0.739644970414
# 0.760355029586
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.683431952663
# 0.695266272189
# 0.733727810651
# 0.760355029586
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.674556213018
# 0.704142011834
# 0.736686390533
# 0.754437869822
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.757396449704
# 0.742603550296
# 0.789940828402
# 0.798816568047
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.674556213018
# 0.701183431953
# 0.760355029586
# 0.775147928994
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.680473372781
# 0.671597633136
# 0.778106508876
# 0.778106508876
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.683431952663
# 0.671597633136
# 0.763313609467
# 0.769230769231
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.686390532544
# 0.677514792899
# 0.781065088757
# 0.778106508876
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.680473372781
# 0.671597633136
# 0.775147928994
# 0.781065088757
# ('exclamation', 'question_mark', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.686390532544
# 0.680473372781
# 0.775147928994
# 0.789940828402
# ('exclamation', 'question_mark', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.674556213018
# 0.692307692308
# 0.751479289941
# 0.781065088757
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.736686390533
# 0.739644970414
# 0.754437869822
# 0.766272189349
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.677514792899
# 0.680473372781
# 0.745562130178
# 0.766272189349
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.704142011834
# 0.698224852071
# 0.745562130178
# 0.751479289941
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.710059171598
# 0.704142011834
# 0.739644970414
# 0.751479289941
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.713017751479
# 0.704142011834
# 0.748520710059
# 0.757396449704
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.704142011834
# 0.698224852071
# 0.748520710059
# 0.751479289941
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.704142011834
# 0.704142011834
# 0.742603550296
# 0.760355029586
# ('exclamation', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.686390532544
# 0.686390532544
# 0.724852071006
# 0.742603550296
# ('exclamation', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.698224852071
# 0.692307692308
# 0.742603550296
# 0.766272189349
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.763313609467
# 0.742603550296
# 0.789940828402
# 0.792899408284
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.665680473373
# 0.671597633136
# 0.769230769231
# 0.769230769231
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.686390532544
# 0.665680473373
# 0.781065088757
# 0.778106508876
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.686390532544
# 0.665680473373
# 0.775147928994
# 0.778106508876
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.689349112426
# 0.683431952663
# 0.775147928994
# 0.778106508876
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.686390532544
# 0.665680473373
# 0.772189349112
# 0.772189349112
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.692307692308
# 0.671597633136
# 0.775147928994
# 0.781065088757
# ('question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.683431952663
# 0.689349112426
# 0.754437869822
# 0.781065088757
# ('question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.674556213018
# 0.656804733728
# 0.781065088757
# 0.789940828402
# ('pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.704142011834
# 0.686390532544
# 0.757396449704
# 0.769230769231
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength')
# 0.754437869822
# 0.754437869822
# 0.772189349112
# 0.784023668639
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'number_number')
# 0.680473372781
# 0.686390532544
# 0.754437869822
# 0.769230769231
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg_strength', 'number_number')
# 0.695266272189
# 0.686390532544
# 0.775147928994
# 0.781065088757
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'neg', 'neg_strength', 'number_number')
# 0.692307692308
# 0.683431952663
# 0.763313609467
# 0.772189349112
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.704142011834
# 0.695266272189
# 0.766272189349
# 0.766272189349
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.695266272189
# 0.686390532544
# 0.763313609467
# 0.769230769231
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.695266272189
# 0.686390532544
# 0.772189349112
# 0.778106508876
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.689349112426
# 0.707100591716
# 0.739644970414
# 0.769230769231
# ('exclamation', 'question_mark', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.686390532544
# 0.677514792899
# 0.775147928994
# 0.784023668639
# ('exclamation', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.715976331361
# 0.707100591716
# 0.751479289941
# 0.757396449704
# ('question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.701183431953
# 0.677514792899
# 0.784023668639
# 0.784023668639
# ('exclamation', 'question_mark', 'pos_vs_neg', 'pos_strength', 'pos_vs_neg_strength', 'pos', 'num_slang', 'avg_word_len', 'neg', 'neg_strength', 'number_number')
# 0.710059171598
# 0.692307692308
# 0.769230769231
# 0.772189349112

# %%
clf.predict_proba(list(data['feature'][0].values()))
# Out:
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([[ 0.26056572,  0.73943428]])

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

base_estimators = [DecisionTreeClassifier(max_depth=1),
                   DecisionTreeClassifier(max_depth=2),
                   DecisionTreeClassifier(max_depth=3)]
n_estimators = np.logspace(2,3,4)
# Create and fit an AdaBoosted decision tree
bdt = AdaBoostClassifier(learning_rate = 0.1)

# %%
clf = grid_search(bdt,data['feature'],data['sentiment'],dict(base_estimator=base_estimators,n_estimators=n_estimators), cv=10, feature_scaled=True,output=False)
