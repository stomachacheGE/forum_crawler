# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from db_initialize import *
# here we assume that database.db only contains data from healingwell
engine = create_engine('sqlite://///Users/Johnson/Documents/nit/thesis/forum_crawler/database_krebs_for_statistics.db')
Session = sessionmaker(bind=engine)
Base.metadata.bind = engine
session = Session()

# %%
import re
def word_count(doc):
    """Function to count number of words in a string."""
    count = len(re.findall(r'\w+', doc))
    return count

# %%
from matplotlib import pyplot as plt
from matplotlib import style
from matplotlib2tikz import save as tikz_save
import numpy as np
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
#plt.rcParams['image.cmap'] = 'gray'

# %%
thread = session.query(Thread).all()
#print(len(thread.posts))
for x in range(1,20):
    print("Word Count: %d" % word_count(thread[x].body))
    print(thread[x])
    #print(len(thread[x].posts))
# Out:
# Word Count: 487
#
# Title: Cheaper version of pricey prostate cancer drug.
# User: FoxRun
# Time: 2016-08-31 18:54:00
# Posts: 3
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3693749
# Biolyse Pharma stymied in effort to make cheaper version of pricey prostate cancer drug.
#
# A small Canadian company has waded into a U.S. drug price controversy by offering to make an expensive prostate cancer drug for a fraction of the price.Right now Xtandi costs U.S. patients as much as $129,000 US a year, or about $90 per pill. St. Catharines, Ont.-based Biolyse Pharma says it can make the drug for $3 a pill, or $4,400 per year, but has so far been unable to get U.S. health authorities to override the existing patent.Biolyse Pharma initially made the offer to make a cheaper version of Xtandi (enzalutamide) to the U.S. government in April. The issue resurfaced last week after pharmaceutical giant Pfizer announced it will pay $14 billion US to buy Medivation, the makers of the drug, primarily on the strength of Xtandi. Medivation, along with Astellas Pharma Inc.of Japan, which owns the drug rights outside the U.S., licensed the patents for Xtandi from the University of California, Los Angeles, where the drug was discovered. Much of the early research and development was publicly funded, and that means U.S. federal agencies have a legal right to override the patents under certain circumstances. Used by a minority of prostate cancer patients
# Enzalutamide is commonly prescribed to men who no longer respond to traditional prostate cancer treatments and prevents the hormone testosterone from fuelling the growth of cancer.
#
# "It's [for] men who have demonstrated metastasis or spread," said Dr. Antonio Finelli, head of the urology division at Princess Margaret Cancer Centre in Toronto.
#
# Of the overall population of men with prostate cancer, only a minority fall into that category.
#
# "It's a drug that definitely has had a significant impact on men who, unfortunately, develop this late-stage prostate cancer," he said.
#
# 'A more reasonable price'
#
# The drug costs $20.12 US a tablet in Canada and $88.48 in the United States, and patients normally need four tablets a day, according to Knowledge Ecology International, a non-profit pharmaceutical industry watchdog in Washington, D.C., that is lobbying to get the price of Xtandi lowered.
#
# ANALYSIS | Secrets and lies: Faked data and lack of transparency plague global drug manufacturing
# INTERACTIVE |  Do you know where your pills come from?
# Knowledge International approached Biolyse earlier this year and asked whether the company could make a more affordable version of the drug for U.S. Medicare patients. Biolyse, which had worked with Knowledge International on affordable access to another cancer drug, pa***axel, did the math and concluded that it could produce a generic version of Xtandi for just $3 a tablet.
#
# "We looked at it and came to the conclusion that it can be offered at a much more reasonable price," said Claude Mercure, a manager at Biolyse.
#
#
# www.cbc.ca/news/health/prostate-cancer-xtandi-1.3742153
#
# Word Count: 27
#
# Title: NOLA Doc
# User: Concerned56
# Time: 2016-08-28 23:45:00
# Posts: 4
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3691941
# Does anyone have any experience or feedback on Dr. Vanlangendonck - in New Orleans who performs DaVinci robotic prostatectomies? Husband recently diagnosed after biopsy - Gleason 7
# Thanks! SC
#
# Word Count: 230
#
# Title: Personal Experience with Diet and Exercise
# User: cashlessclay
# Time: 2015-10-14 11:43:00
# Posts: 64
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3515667
# After surgery and radiation (SRT) have failed to stop
# a rising PSA, I decided to get serious about diet and
# exercise.  Now I have 2 1/2 years of data using the
# Labcorp Ultrasensitive test and careful notes on what
# I eat.
#
# With a Gleason score of 6, and a PSA doubling time
# (PSADT) of about 7 months post surgery AND post
# radiation, I am trying maximize the DT through diet
# and exericise.
#
# My PSADT went from 7 months to currently over 5 years.
#
# This is what I'm doing .... may not work for everybody.
#
# 1)  I make sure supplements do not contain
#      Chondroitin Sulfate nor Iron.
#
# 2)  Minimize an insulin response.  The less sugar and
#      fast carbs, the better the results.
#
# 3)  No red meat, no eggs, very little dairy (Gouda).
#
# 4)  Basic diet is (organic) vegan with seafood.  But, no
#      farmed raised fish.
#
# 5)  Lots of raw vegetables, especially broccoli and
#      broccoli sprouts.  Have with hummus containing
#      olive oil, and add turmeric spice, ground black pepper,
#      rosemary, and oregano to the hummus.
#
# 6)  Use Olive oil when you need oil.
#
# 7)  Brown over white for carbs if you have to.
#
# 8)  Some soy product daily, mostly soy beans, milk or tofu.
#
# 9)  I have green tea every day (1 or 2 cups).
#
# 10)  Vitamin D-3 or sunshine and a brisk walk 30 to 45 min.
#        per day.
#
# Word Count: 61
#
# Title: Custirsen fails another phase 3 trial and appears nonviable
# User: RobertC
# Time: 2016-08-16 07:38:00
# Posts: 3
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3684353
# custirsen has failed the second of three late-stage trials in prostate cancer. This time, in a study called Affinity, custirsen, when combined with the steroid prednisone and the chemotherapy cabazitaxel, didn’t help extend the lives of prostate cancer patients who had already failed a round of chemo. In 2014, custirsen failed a trial in newly diagnosed prostate cancer patients.
#
# Word Count: 393
#
# Title: Initial RO Consult About Salvage Treatment
# User: Graytech
# Time: 2016-08-24 10:32:00
# Posts: 16
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3689266
# Had my initial consult with an RO and his resident on Monday.
#
# In summary, I will do another PSA in 2 months and if I'm above .07 begin 6 months of Lupron (oh joy) and 25 hypofractionated radiation treatments 5 days a week after the holidays. Will not be doing the lymph nodes.
#
# We discussed the three articles I sent him via Email.  Both he and the resident said thank you for sending them ahead of time rather than dumping them on the desk at the appointment. (Thank you Tall Allen for suggesting it) The three I sent were all deemed to be from reliable sources.
#
# RO said the articles all line up with other recent studies he had seen and agreed with the Koulikov article conclusion. He said I could go ahead with treatment now or do another PSA in 2 months. He referenced the article and said he has had some patients, not many, that did stabilize between .03 and .07 for years after rising in a similar fashion and pathology as mine. According to his own patient data a uPSA level of .07 doesn't correlate to 100% BCR failure at 5 years. Even though I met the Koulikov criteria for treatment now he felt waiting 2 months for confirmation was prudent and would not significantly compromise my outcome.  I made the decision to wait the 2 months and retest.
#
#
# Questions/Answers we discussed.
#
# - No imaging prior to SRT, won't reliable show anything with a PSA this low, already had a baseline done.
# - No other blood tests now, not reliable enough to change the treatment plan.
# - Anatomy changes so planning ahead of time without doing treatment ASAP is a bad idea.
# - PNI+ adverse path finding does not correlate to any increased risk or escape route.
# - Side effects are the expected ones, he didn't try to down play them.
# - Full bladder during radiation but no rectal spacer gel / balloon etc. (happy about this one)
# - No change in diet unless it becomes necessary.
# - Monthly PSA testing now would be pointless. Not likely to show any change.
# - Continue daily Cialis but ED will be both a short (Lupron) and may be a long term (Radiation) SE.
# - Incontinence may be a short term SE, hopefully not long term.
# - Retention may also be an issue especially due to my previous stricture.
#
#
# Jon
#
# Word Count: 162
#
# Title: OT: Every time I am almost ready to go vegan LOL!
# User: BillyBob@388
# Time: 2016-08-10 08:15:00
# Posts: 4
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3680848
# I guess the subject remains debatable!
# /www.thesun.co.uk/news/1584689/parents-who-force-vegan-diets-on-their-kids-may-face-four-years-in-jail-in-italy-because-it-could-leave-them-brain-damaged/
# Somebody said...
# .....................The country has been rocked in recent months by a series of child hospitalisations caused by vegan diets.
#
# Last month, a 14-month-old baby was taken to hospital with the expected weight of a three-month-old.
#
# It emerged he had been subjected to a vegan diet, leaving him dangerously malnourished and with low calcium levels.
#
# According to Repubblica, Savino said: “For years now, and particularly in the last decade, the belief has been spreading that a vegetarian diet, even in its most rigid form as a vegan diet, provides substantial contributions to health.
#
# “The problem arises when children are to be involved.”...............
#
# Not sure what science, if any, these folks are basing this on, but obviously there are some different opinions out there.
#
# Word Count: 325
#
# Title: Against all odds
# User: celebrate life
# Time: 2016-08-10 12:47:00
# Posts: 32
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3680792
# When Gary decided to end the immunotherapy pilot study with liver mets and a PSA of 900 in May, 2015, he told the clinician in Portland (Todd's new team) that he wanted to spend as much time as he had left with quality of life just living.  It was his Hail Mary and it failed.  But he also returned to our local medonc to give some past tx a second go-round.
# Docetaxil and xtandi kept him going until February of this year.  But with a psa reaching nearly 1500, it looked like he had exhausted his options.
# Then the medonc said he wanted to try a very old and no longer used as protocol chemo called mitoxantrone.  Bet you haven't even heard of it (except TA of course)  The medonc made out like this was his Hail Mary and none of us had much faith.  I didn't even add it to my Sig line.   Well it's there now.  After 7 cycles Gary's psa has steadily dropped from 1416 in March to 792 today!  A steady decrease of 200 points per tx!!!
# Two weeks ago his weight had fallen to a low of 113 pounds.  Another Hail Mary med, carafate, has helped his vomiting, good weed and constantly putting food in front of him has increased his appetite, and a diuretic, spironolactone, has taken care of the ascites fluid. Today he weighed 120.  He gained 7 lbs in two weeks.    He is no longer sleeping through the day and is resuming some activity.  In October he will turn 58, against all odds and expectations (well, I myself have always expected him to beat the odds).
# If I were in Gary's shoes, I'm sure I would have called it quits long ago.  He is my hero and my inspiration.  Thank you all my HW friends for helping us through this journey.  We aren't done yet!!!
# Beth for Gary
#
#
#
# Word Count: 157
#
# Title: Woohoo!
# User: cfbbneil
# Time: 2016-08-06 10:27:00
# Posts: 7
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3678963
# Had a follow up visit with the Urologist yesterday, talking about leaking, how things are going etc - had RALP at Johns Hopkins on 7/5.  As we were finishing up, she gave me a one month supply of Cialis 5g, and recommended starting to take it every other day.  Also gave me some info on medical grade vacuum pump.
#
# So after we got home, we realized we had the house to ourselves, so started fooling around, and low and behold, much to our surprise, a serviceable erection!  I've read comments about how orgasm would be different and possibly more intense - different and intense indeed.  Wasn't sure if I was going to pee (didn't) or what - almost felt like the first time!  Left us smiling the rest of the day.
#
# Starting the Cialis today.  Thoughts on the pumps?
#
# Have a great weekend everybody!Post Edited (cfbbneil) : 8/6/2016 9:30:31 AM (GMT-6)
#
# Word Count: 120
#
# Title: Saw Uro, opinions please
# User: rpw612
# Time: 2016-05-06 00:19:00
# Posts: 24
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3630428
# Hello,
#
# My psa without meds peaked at 8.3 in Oct 2014, going up steadily since Jan. 2014 with a 53cc prostate.(per MRI 9/2014 which was normal but said bph).
#
# Went on proscar and flomax since then.  Psa has steadily been dropping to 2.5 as of late Nov. 2015 with a 30cc prostate estimated from DRE.
#
# Appointment today psa 4.0, and still on proscar and flomax.
# Dr. Says he's not worried as he has seen this before, but is having me come back in three months instead of six for another psa and he added a % free psa.
#
# DRE was completely normal with a prostate size of 30cc estimated from DRE.
#
# Thank you for opinions.
#
# Word Count: 242
#
# Title: Biopsy results
# User: Mermaid88
# Time: 2016-07-30 09:55:00
# Posts: 7
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3675333
# Well, it's good news! If one can consider a diagnosis of PC good news! Anyone who has read my previous posts regarding my Dad's doubling PSA in a year while on Finasteride (from 3.5 -7)....he had the MRI several weeks ago, which showed a 1cm area of concern and was followed up by a fusion biopsy last Monday. The doctor called yesterday to give the biopsy results and Dad will go in for a follow-up consultation to have them explained in more detail.
#
# But- the main thing is that his Urologist conveyed over the phone that the few cancer cells that were found were low grade - not the "life threatening kind". I'm sure we will receive the detailed pathology report when we go to the appointment and find out whether treatment is necessary and what type.
#
# Based on what I've read and statistics show that it was likely there would be some cancer cells in the biopsy... But we are relieved it is low grade and treatable if necessary!
#
# Thanks to everyone's input and moral support through this! I have shared everyone's input with my Dad, who is extremely grateful!
#
#
# Dad's age 71
# Has been monitoring PSA for 10 years.
# 2 previous biopsies negative, 2007 and 2011
# 2016 recent PSA rose from 3.5-7 in a year
# MRI found 1cm area of concern
# Fusion Biopsy confirmed some cancer cells - low grade.
#
# Word Count: 51
#
# Title: book reccomendation
# User: Bololidat
# Time: 2016-07-28 23:25:00
# Posts: 2
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3674619
# Escape from Freedom...Erich Fromme
#
# basic thesis is that folks want to escape from freedom and the personal griefs and responsibilities associated with that. Oop...hence seeking other institutions  to decide for them... Dont get excited..not accusing...but its a revealing read... of course it would be your decision...lol
#
# Word Count: 182
#
# Title: Help 1 week and 3 days post Robotic surgery
# User: Natashamac
# Time: 2016-07-21 11:06:00
# Posts: 8
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3670586
# I'm here for a friend. We don't live in the same state. He underwent Robotic Surgery last Monday. I don't know the details of the surgery. He's been in horrible pain. He stayed in th the hospital 3 days. He has 6 incisions on his stomach, all but one has healed and it's leaking. He has a cathera. When he went home he developed swelling of his penis. He was alarmed so he returned to the hospital. They kept him 2 more days before releasing him. Back home in more pain and returned to the hospital again. He's unable to take the narcotic pain relievers because of an allergic reaction. He has bruising on the left side of his body from his chest to his thigh. Is this normal? Doc suggested a pill that may help him with the incision leaking issue to avoid another surgery. He's in such pain and frustrated that he wants to be transferred to another hospital. Please what are your thoughts? He needs help
#
# Sincerely,
# A friend trying to help
#
# Word Count: 174
#
# Title: New member of G9 club.
# User: Larry E
# Time: 2016-07-17 10:08:00
# Posts: 8
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3668014
# G9 crew checking in - I live in Skiatook Oklahoma; I am a math teacher for the last 28 years and still am, I report back to school in 3 weeks.
#  I changed oncologist last month in hopes of getting referred to a major Prostate cancer doctor. My new Oncologist is with Oklahoma Cancer Specialists and Research Institute they are affiliated with MD Anderson.
#  I saw my new medical oncologist last week, because I am having new pain in my back and in my hip when sitting; with no PSA rise. The new oncologist scheduled 3 MRIs on my spine (Monday 7/18); also wants me to see his radiology oncologist (Friday 7/22). Do you have any questions I should ask the radiology oncologist? I don’t know what he might suggest.
# I would like to see Dr. Kwon (c11 pet scan) at Mayo, but it may end up being easier to get to MD Anderson. Do you have any advice about how to get referred to a doctor who specializes in prostate cancer?
#
# Word Count: 626
#
# Title: My Father
# User: halbert
# Time: 2016-07-18 05:33:00
# Posts: 15
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3668406
# Cyclones post about JPENN starting me thinking, and remembering another of our brothers--and my father.  So, I'm not sure where this is going to go, but here it is.
#
# He would have been 90 on Saturday, July 16, except this disease took him from this world on October 18, 2004.  I'm thinking about him now in particular because I'm at the place where his presence is strongest.  He was born the son of millworkers in one of the major New England textile towns.  Neither of his parents went past 8th grade in their educations--but they went to the library every week and were voracious readers.
#
# He joined the Navy in the summer of '44 (it was volunteer or get drafted time), went through basic in upstate New York, and got posted to radio school in Chicago.  He was at Navy Pier on VJ day and experienced the VJ day celebrations in the Loop.  After a brief tour of duty, he was discharged in time to enroll at Northwestern for the class of 1950.
#
# He majored in Organic Chemistry, received a Masters at Northwestern, met my mother, was married in 1952, and went on to receive his PhD at what was then Carnegie Institute of Technology in Pittsburgh.  After a time at Duke University, he received a permanent teaching position at Baldwin-Wallace College in 1958, and taught there for the next 30+ years.
#
# When PC hit in the early 90's (sorry, I don't remember which year, I think it was 1991, when he turned 65), PSA was just coming into common use.  Again, I don't have the details.  What I do know is that following his diagnosis, he applied his research mind, and chose to participate in the early use of whole-gland cryotherapy project at Cleveland Clinic.  I recall from what he told me then, that he did it because of the opportunity to do something cutting edge, rather than submit to open surgery--which, as I recall, was still primarily the trans-perineal method.
#
# He had what looked like amazing results from the cryotherapy.  Within 6 months his PSA had hit nadir, a DRE indicated that his prostate was "gone".  They traveled with Elderhostel, spending time in Asia Minor, Australia/New Zealand, and other spots.  They spent several summers in England.  He thoroughly enjoyed his granddaughters.
#
# In about 2000, his PSA started back, and he went on HT.  I think, again, at the time it was before Lupron, so he was on synthetic estrogen, one shot a month.  That lasted a couple of years, then they found cancer growing on his Ureters.  He had radiation treatments on that, finishing in the spring of 2004.  Early that summer he took a fall and it appeared that he injured his tailbone.  He had gradually worsening back pain all that summer, and in August that year he was found to have spinal mets.  As I said at the heading, he passed in October that year.
#
# When I look at his battle, I keep coming back to the reality that he chose the path he took, at least in part, because of the research angle.  He wanted to be a pathfinder, a test subject.  He knew, that even if things ultimately didn't turn out for the best, that the research had to be done, that the questions needed answers.
#
# I wish I was that courageous.
#
# One day this week, I'll stop off at the cemetery.  He's in a small village graveyard here in Maine.  On the back of the headstone is a quote from Chaucer, "The lyfe so short, the craft so long to lerne".  RES--Father, teacher, researcher, renaissance man.  He never stopped learning, or teaching.
#
# Word Count: 127
#
# Title: 2 1/2 year update Still Undetectable
# User: sbharley
# Time: 2016-07-14 15:01:00
# Posts: 2
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3666770
# Hello to all, 5 July 2016 was my 30 month post op anniversary.  Still less than 0.04 psa as it was at 4 weeks post Da Vinci.  Thank you to all for the support.  Leaking still, not much, but bothersome now.  I will be undertaking urodynamics on 24 August and I'm really leaning towards the bladder bulking procedure instead of the advance sling.  Any suggestions?  I leak about a shot glass a day, some positions make me vulnerable, and sex, forget it.  If I even then about arousal, I start spitting like I'm chewing Red Man again!!!  Erections are about 90 % with and without Cialis, so I stopped altogether.
#
# Anyway, still undetectable and that's what counts.  Quality of life issues now prevail.
#
# Bob
#
# Word Count: 12
#
# Title: Should we stop or continue with psa testing for the male population
# User: Bololidat
# Time: 2016-07-08 22:44:00
# Posts: 53
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3663888
# This hasn' been discussed recently...let's give er a go...whot???
#
# Word Count: 356
#
# Title: When your doctor tells you that he is no longer your doctor: what next? (Article)
# User: 81GyGuy
# Time: 2016-07-08 09:22:00
# Posts: 7
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3663556
# Purgatory has reported in a concurrent thread that the physician overseeing his treatment for the past five years has left, apparently under unclear circumstances as to why, leaving David having to scramble now to find a new doctor.
#
# While perhaps most of us have never faced this unexpected and likely unpleasant situation, and hopefully never will (although there may have been occasions when it was we who left the physician), it's obviously going to be a troublesome matter. Especially if it happens out of the blue, as it apparently has for David.
#
# The article below is by a physician on this subject.
#
# At first the author laments that many of the circumstances of practicing modern medicine have made it so difficult for some physicians, that leaving medicine altogether has become an option for them. That leaves their patients to find new providers, usually rather quickly, and which, the author reports, is becoming more and more difficult to do in many areas. ("Areas" in both senses of the word, both geographical and clinical specialty).
#
# He then mentions the emotional impact that this can have on some patients, especially if they have been with the physician for a long time and prefer that person, and the news that he or she is leaving has been abrupt and unexpected.
#
# He then discusses how insurance issues can hamper the patient's search for a new provider, that it's not as simple a thing as finding a new doctor one likes, but that the patient's insurance has to go along with this choice, and not impose restrictions. (The author's advice: as soon as you learn that your physician is leaving, contact your insurance carrier immediately to begin the process of finding a new provider acceptable to your carrier).
#
# Ideally, a physician will announce departure or termination of practice with enough lead time to allow patients to find other resources.
#
# But not always, and having at least an idea of what to do next in such short-notice circumstances is clearly a good thing.
#
# A good read:
#
# www.kevinmd.com/blog/2010/07/doctor-quits-leaves-medicine.html
#
# Word Count: 233
#
# Title: (No Subject)
# User: Nell79
# Time: 2016-07-12 19:00:00
# Posts: 1
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3665738
# I'm wondering if your wife might be in denial.  We all go thru these steps when faced with life threatening illness.  I know Charlie accepted his diagnosis much sooner than I did and I'm sure I wasn't as supportive or empathetic as I should have been.  It is difficult when you look good and are still functioning well and then we don't want you to be sick so we can tell ourselves you are not sick and block it out easier than you can.  As Charlie's disease has progressed I realized that I had been in denial longer than he was and I feel sad.  I am now more attuned to his feelings, symptoms and pain.  Communication is key, difficult to do but it is a necessity. Don't be fearful of asking for what you need or want-she will only be able to provide if you tell her.  Does your wife go with you to your dr appointments?  It might help her get more in tuned to what's happening.  I don't feel our family-esp Charlie's parents and sisters are very supportive but thru counseling I have learned to accept how "it is" and forget about how I think "it should be"! Good luck and prayers for you and your family.Post Edited (Nell79) : 7/12/2016 6:03:43 PM (GMT-6)
#
# Word Count: 19
#
# Title: PSA update, Proton Therapy
# User: stixandstonz
# Time: 2016-07-12 19:45:00
# Posts: 4
# URL: http://www.healingwell.com/community/default.aspx?f=35&m=3665757
# 42 month post Proton radiation treatment, steady at 0.3.
#
# All is good, time for a beer.
#
# Regards,
# Kris

# %%
def show_statistics(array):
    import numpy as np
    print("Median is %f;" % np.median(array))
    print("Mean is %f;" % np.mean(array))
    print("Maximum is %f;" % np.max(array))
    print("Minmum is %f;" % np.min(array))

# %% [markdown]
# ## Distributions of  participants’ contribution (initial posts) to the online forum.

# %%
#total number of users
num_users = session.query(User).count()
print("Total number of users: %d" % num_users)
#total number of threads
num_threads = session.query(Thread).count()
print("Total number of threads: %d" % num_threads)
#total number of posts
num_posts = session.query(Post).count()
print("Total number of posts: %d" % num_posts)
# Out:
# Total number of users: 2328
# Total number of threads: 9974
# Total number of posts: 69089

# %%
users = session.query(User).all()
for user in users:
    if user.id < 1000:
        print(user)

# %%
user_threads = np.array([len(user.threads) for user in users])

# %%
np.save('outputs/user_threads_krebs', user_threads)

# %%
user_threads = np.load('outputs/user_threads_krebs.npy')

# %%
show_statistics(user_threads)
# Out:
# Median is 1.000000;
# Mean is 4.284364;
# Maximum is 416.000000;
# Minmum is 0.000000;

# %%
user_posts = np.array([len(user.posts)+len(user.threads) for user in users])

# %%
np.save('user_posts', user_posts)

# %%
user_posts = np.load('outputs/user_posts_krebs.npy')

# %%
show_statistics(user_posts)
# Out:
# Median is 4.000000;
# Mean is 33.961770;
# Maximum is 2805.000000;
# Minmum is 1.000000;

# %%
ini_bincount = np.bincount(np.squeeze(user_threads))
ini_prob = ini_bincount / user_threads.shape[1]
total_bincount = np.bincount(np.squeeze(user_posts))
total_prob = total_bincount / user_posts.shape[1]
style.use('ggplot')
plt.yscale('log')
plt.xscale('log')
plt.title('Distributions of  participants’ contribution (initial posts) to the online forum.')
plt.xlabel(r'Number of posts $N$')
plt.ylabel(r'Prob. that a user has $N$ posts')
plt.plot(np.arange(len(ini_prob)), ini_prob, 'ro', label='Inital Posts')
plt.plot(np.arange(len(total_prob)), total_prob, 'wo', label='Total Posts')
#plt.xlim([-0.1, max(user_posts)])
plt.legend()
plt.grid(True)

#plt.show()
# We can also save the figure to .tex format
tikz_save('outputs/user_posts_krebs.tex')
# Out:
# file encoding: UTF-8
# =========================================================
# Please add the following lines to your LaTeX preamble:
#
# \usepackage[utf8]{inputenc}
# \usepackage{fontspec}
# \usepackage{pgfplots}
# \usepgfplotslibrary{plotmarks}
# =========================================================

# %%
user_threads_1 = np.sort(np.squeeze(user_threads))
#change to descending order
user_threads_2 = user_threads_1[::-1]
style.use('ggplot')
#plt.yscale('log')
#plt.xscale('log')
plt.title('Distribution of the number of threads for each user.')
plt.xlabel(r'User')
plt.ylabel(r'Number of threads')
plt.plot(np.arange(len(user_threads_2)), user_threads_2, 'ro')
#plt.legend()
plt.grid(True)

#plt.show()
tikz_save('outputs/users_threads_krebs_trival.tex')
# Out:
# file encoding: UTF-8
# =========================================================
# Please add the following lines to your LaTeX preamble:
#
# \usepackage[utf8]{inputenc}
# \usepackage{fontspec}
# \usepackage{pgfplots}
# \usepgfplotslibrary{plotmarks}
# =========================================================

# %% [markdown]
# ## Distribution of the number of replies to threads in the forum.

# %%
threads = session.query(Thread).all()

# %%
num_thread = session.query(Thread).count()
thread_posts = np.empty([1, num_thread],dtype="int32")
print(thread_posts)
#thread_posts = np.array([len(thread.posts) for thread in threads])
for i in range(1, num_thread+1):
    thread = session.query(Thread).get(i)
    thread_posts[0,i-1] = len(thread.posts)
    if i%50==0:
        print("%d/%d" % (i,num_thread))

# %%
# Alternatively, this single line also does the job, but we can not check progress
thread_posts = np.array([len(thread.posts) for thread in threads])

# %%
# save the array to .npy file on disk for later use
np.save('outputs/thread_posts_krebs', thread_posts)

# %%
thread_posts = np.load('outputs/thread_posts_krebs.npy')

# %%
show_statistics(thread_posts)
# Out:
# Median is 2.000000;
# Mean is 6.926910;
# Maximum is 672.000000;
# Minmum is 0.000000;

# %%
post_bincount = np.bincount(np.squeeze(thread_posts))
post_prob = post_bincount / thread_posts.shape[1]
print(thread_posts.shape[1])
style.use('ggplot')
plt.yscale('log')
plt.xscale('log')
plt.title('Distribution of the number of replies to threads in the forum.')
plt.xlabel(r'Number of replies $N$')
plt.ylabel(r'Prob. that a thread has $N$ replies')
plt.plot(np.arange(len(post_prob)), post_prob, 'ro')
#plt.legend()
plt.grid(True)

plt.show()
#tikz_save('outputs/number_replies_krebs.tex')
# Out:
# 9974
# file encoding: UTF-8
# =========================================================
# Please add the following lines to your LaTeX preamble:
#
# \usepackage[utf8]{inputenc}
# \usepackage{fontspec}
# \usepackage{pgfplots}
# \usepgfplotslibrary{plotmarks}
# =========================================================

# %%
thread_posts_1 = np.sort(np.squeeze(thread_posts))
#change to descending order
thread_posts_2 = thread_posts_1[::-5]
style.use('ggplot')
#plt.yscale('log')
#plt.xscale('log')
#plt.title('Distribution of the number of replies to threads.')
plt.xlabel(r'Thread')
plt.ylabel(r'Number of replies')
plt.plot(np.arange(len(thread_posts_2))*5, thread_posts_2, 'ro')
#plt.legend()
plt.grid(True)

plt.show()
#tikz_save('outputs/number_posts_krebs_trival.tex')
# Out:
# file encoding: UTF-8
# =========================================================
# Please add the following lines to your LaTeX preamble:
#
# \usepackage[utf8]{inputenc}
# \usepackage{fontspec}
# \usepackage{pgfplots}
# \usepgfplotslibrary{plotmarks}
# =========================================================

# %% [markdown]
# ## Distribution of the time span of threads in the forum.

# %%
# function to get time span in hours
from datetime import datetime
def get_time_span(thread):
    #post_timestamps = np.array([post.timestamp for post in thread.posts], dtype='datetime64')
    # assume the last post in thread.posts is the last reply
    thread_time = datetime.strptime(thread.timestamp, '%Y-%m-%d %H:%M:%S')
    # if there is no reply, retrun 0 as time span
    if not thread.posts:
        return 0
    last_reply_time = datetime.strptime(thread.posts[-1].timestamp, '%Y-%m-%d %H:%M:%S')
    time_delta = last_reply_time - thread_time
    # calculate the time span in hours
    time_span = 24*int(time_delta.days) + time_delta.seconds//3600
    # if time span smaller than 0, there must be something wrong.
    if time_span < 0:
        print('Found unusual thread, ID is %d' % thread.id)
    return time_span

# %%
num_thread = session.query(Thread).count()
thread_timespan = np.empty([1, num_thread],dtype="int32")
#thread_posts = np.array([len(thread.posts) for thread in threads])
for i in range(1, num_thread+1):
    thread = session.query(Thread).get(i)
    thread_timespan[0,i-1] = get_time_span(thread)
    if i%50==0:
        print("Processing %d/%d" % (i, num_thread))
print("Saving to file..")
np.save("thread_timespan", thread_timespan)

# %%
thread_time_spans = np.load('outputs/thread_timespan_krebs.npy')

# %%
show_statistics(thread_time_spans)
# Out:
# Median is 15.000000;
# Mean is 1307.171947;
# Maximum is 80805.000000;
# Minmum is 0.000000;

# %%
print(thread_time_spans[0:5])
num_thread = thread_time_spans.shape[1]
negative = thread_time_spans<0
# Due to a bug in crawling, the time 12:34 PM will be stored as 00:34,
# which causes negative time span. This has to be corrected.
thread_time_spans[thread_time_spans<0] += 12
print(thread_time_spans[0:5])
# Due to another unknown bug, there are still negative time spans.
# Correct them by change its sign.
thread_time_spans[thread_time_spans<0] -= 12
thread_time_spans[thread_time_spans<0] = -thread_time_spans[thread_time_spans<0]
print(thread_time_spans[0:5])
np.sum(thread_time_spans<0)
#thread_time_spans[thread_time_spans<0]
ok,problems = np.where(thread_time_spans<0)
print(problems)
for i in range(len(problems)):
    thread = session.query(Thread).get(problems[i]+1)
    print(problems[i]+1)
    print(thread.url)
# Out:
# [[ 114   13   23 ...,   13    2 1270]]
# [[ 114   13   23 ...,   13    2 1270]]
# [[ 114   13   23 ...,   13    2 1270]]
# []

# %%
timespan_bincount = np.bincount(np.squeeze(thread_time_spans))
timespan_prob = timespan_bincount / thread_time_spans.shape[1]
style.use('ggplot')
plt.yscale('log')
plt.xscale('log')
plt.title('Distribution of the time span of threads in the forum.')
plt.xlabel(r'Life span $T$ of a thread (in hours)')
plt.ylabel(r'Prob. that a thread has a life span of $T$ hours')
#plt.plot(np.arange(len(timespan_prob)), timespan_prob, 'ro')
# since large figure file may exceed latex capactity,
# downsampling are needed.
first = np.arange(1000)
second = np.rint(np.linspace(1000,len(timespan_prob),5000, endpoint=False))
second = second.astype(int)
index = np.concatenate((first, second))
plt.plot(index, timespan_prob[index], 'ro')
#plt.legend()
plt.grid(True)
#tikz_save('outputs/thread_time_span_krebs.tex')
plt.show()
# Out:
# file encoding: UTF-8
# =========================================================
# Please add the following lines to your LaTeX preamble:
#
# \usepackage[utf8]{inputenc}
# \usepackage{fontspec}
# \usepackage{pgfplots}
# \usepgfplotslibrary{plotmarks}
# =========================================================

# %% [markdown]
# ## Distribution of the number of words in (initial) posts in the forum.

# %%
thread_word_count = np.load('outputs/thread_word_count_krebs.npy')
num_thread = thread_word_count.shape[1]
print(num_thread)
# Out:
# 9974

# %%
show_statistics(thread_word_count)
# Out:
# Median is 115.000000;
# Mean is 186.356828;
# Maximum is 7254.000000;
# Minmum is 0.000000;

# %%
post_word_count = np.load('outputs/post_word_count_krebs.npy')
num_post = post_word_count.shape[1]
print(num_post)
# Out:
# 69089

# %%
show_statistics(post_word_count)
# Out:
# Median is 91.000000;
# Mean is 136.059561;
# Maximum is 6263.000000;
# Minmum is 0.000000;

# %%
thread_bincount = np.bincount(np.squeeze(thread_word_count))
thread_prob = thread_bincount / num_thread
post_bincount = np.bincount(np.squeeze(post_word_count))
post_prob = post_bincount / num_post
style.use('ggplot')
plt.yscale('log')
plt.xscale('log')
plt.title('Distribution of the number of words in (initial) posts in the forum.')
plt.xlabel(r'Number of words $N$')
plt.ylabel(r'Prob. that a (initial) post has $N$ words')
#plt.plot(np.arange(len(thread_prob)), thread_prob, 'ro', label='Inital Posts')
#plt.plot(np.arange(len(post_prob)), post_prob, 'wo', label='Reply Posts')
# since large figure file may exceed latex capactity,
# downsampling are needed.
#index = np.arange(10000)
first = np.arange(1000)
second = np.rint(np.linspace(1000,len(post_prob),5000))
second = second.astype(int)
index = np.concatenate((first, second))
#plt.plot(index, timespan_prob[index-1], 'ro')
plt.plot(np.arange(len(thread_prob)), thread_prob, 'ro', label='Inital Posts')
plt.plot(index, post_prob[index-1], 'wo', label='Reply Posts')
plt.legend()
plt.grid(True)
tikz_save('outputs/post_wordcount_krebs.tex')
plt.show()
# Out:
# file encoding: UTF-8
# =========================================================
# Please add the following lines to your LaTeX preamble:
#
# \usepackage[utf8]{inputenc}
# \usepackage{fontspec}
# \usepackage{pgfplots}
# \usepgfplotslibrary{plotmarks}
# =========================================================

# %% [markdown]
# ## Training data selection

# %%
# divide the number of words into 28 intervals, 
# which are stored in ranges. Caculate the probabilities in each range.
prob = []
ranges = []
for i in range(3):
    log = np.log10(np.arange(10))
    index_log = i + log
    index = np.rint(np.power(10, index_log[1:]))
    index_1 = np.rint(np.power(10, index_log))
    #print(index)
    #print(index_1)
    for j in range(len(index)):
        if j < len(index)-1:
            x_range = np.arange(index[j],index[j+1])
            x_range = x_range.astype(int)
            #print(np.sum(thread_prob[x_range]))
            prob.append(np.sum(thread_prob[x_range]))
            #print(prob)
            ranges.append([index[j], index[j+1]])
            #print(x_range)
            #print(prob[m])
        if j == len(index)-1:
            x_range = np.arange(index[j],index[j]+index[0])
            #print(x_range)
            x_range = x_range.astype(int)
            prob.append(np.sum(thread_prob[x_range]))
            ranges.append([index[j], index[j]+index[0]])
            #prob[m] = np.sum(thread_prob[x_range])
            #print(prob[m])
# append the case when word count is bigger than 1000
prob.append(1-sum(prob))
ranges.append([1000, np.max(thread_word_count)])
prob_np = np.array(prob)
ranges_np = np.array(ranges)
print(prob_np)
print(ranges_np)
# Out:
# [ 0.00034722  0.00038194  0.000625    0.00090278  0.00097222  0.00145833
#   0.00163194  0.00142361  0.00211806  0.03458333  0.04239583  0.04822917
#   0.04840278  0.0515625   0.05232639  0.04565972  0.04565972  0.04045139
#   0.29934028  0.1371875   0.06048611  0.03413194  0.01756944  0.00979167
#   0.00729167  0.00402778  0.0028125   0.00822917]
# [[  1.00000000e+00   2.00000000e+00]
#  [  2.00000000e+00   3.00000000e+00]
#  [  3.00000000e+00   4.00000000e+00]
#  [  4.00000000e+00   5.00000000e+00]
#  [  5.00000000e+00   6.00000000e+00]
#  [  6.00000000e+00   7.00000000e+00]
#  [  7.00000000e+00   8.00000000e+00]
#  [  8.00000000e+00   9.00000000e+00]
#  [  9.00000000e+00   1.00000000e+01]
#  [  1.00000000e+01   2.00000000e+01]
#  [  2.00000000e+01   3.00000000e+01]
#  [  3.00000000e+01   4.00000000e+01]
#  [  4.00000000e+01   5.00000000e+01]
#  [  5.00000000e+01   6.00000000e+01]
#  [  6.00000000e+01   7.00000000e+01]
#  [  7.00000000e+01   8.00000000e+01]
#  [  8.00000000e+01   9.00000000e+01]
#  [  9.00000000e+01   1.00000000e+02]
#  [  1.00000000e+02   2.00000000e+02]
#  [  2.00000000e+02   3.00000000e+02]
#  [  3.00000000e+02   4.00000000e+02]
#  [  4.00000000e+02   5.00000000e+02]
#  [  5.00000000e+02   6.00000000e+02]
#  [  6.00000000e+02   7.00000000e+02]
#  [  7.00000000e+02   8.00000000e+02]
#  [  8.00000000e+02   9.00000000e+02]
#  [  9.00000000e+02   1.00000000e+03]
#  [  1.00000000e+03   2.55997600e+06]]
# /Users/Johnson/Documents/nit/thesis/crawler/lib/python3.5/site-packages/ipykernel/__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
# we want only 300 threads for training, 
# thus convert probabilities to numbers
counts = np.rint(prob_np * 350)
counts[np.argmax(counts)] += 350-np.sum(counts)
print(counts)
# Out:
# [   0.    0.    0.    0.    0.    1.    1.    0.    1.   12.   15.   17.
#    17.   18.   18.   16.   16.   14.  106.   48.   21.   12.    6.    3.
#     3.    1.    1.    3.]

# %%
num_thread = thread_word_count.shape[1]
# randomize thread ids
random = np.random.randint(1,num_thread+1,size=num_thread)

# %%
found_count = np.zeros(counts.shape)
#print(np.sum(found_count))
ids = []
for idx in random:
    #print(type)
    # cast to int is important
    thread = session.query(Thread).get(int(idx))
    if not thread:
        print("wrong id:%d" % idx)
    #print(thread)
    wordcount = word_count(thread.body)
    for i in range(ranges_np.shape[0]):
        # if find the wordcount is in a range and there are not enough 
        # threads in that range, add it
        if wordcount in range(*ranges_np[i].astype(int)) and found_count[i]<counts[i]:
            print(*ranges_np[i].astype(int))
            print(wordcount)
            found_count[i] += 1
            ids.append(int(idx))
            print("Collected %d/300 threads" % np.sum(found_count))
# Out:
# 0.0
# 70 80
# 74
# Collected 1/300 threads
# 700 800
# 755
# Collected 2/300 threads
# 70 80
# 78
# Collected 3/300 threads
# 60 70
# 65
# Collected 4/300 threads
# 80 90
# 84
# Collected 5/300 threads
# 200 300
# 210
# Collected 6/300 threads
# 100 200
# 105
# Collected 7/300 threads
# 20 30
# 27
# Collected 8/300 threads
# 70 80
# 73
# Collected 9/300 threads
# 100 200
# 106
# Collected 10/300 threads
# 90 100
# 97
# Collected 11/300 threads
# 300 400
# 303
# Collected 12/300 threads
# 200 300
# 217
# Collected 13/300 threads
# 200 300
# 235
# Collected 14/300 threads
# 100 200
# 182
# Collected 15/300 threads
# 90 100
# 94
# Collected 16/300 threads
# 10 20
# 17
# Collected 17/300 threads
# 70 80
# 72
# Collected 18/300 threads
# 50 60
# 52
# Collected 19/300 threads
# 100 200
# 146
# Collected 20/300 threads
# 70 80
# 71
# Collected 21/300 threads
# 200 300
# 265
# Collected 22/300 threads
# 200 300
# 279
# Collected 23/300 threads
# 100 200
# 179
# Collected 24/300 threads
# 100 200
# 157
# Collected 25/300 threads
# 100 200
# 181
# Collected 26/300 threads
# 200 300
# 292
# Collected 27/300 threads
# 300 400
# 340
# Collected 28/300 threads
# 100 200
# 140
# Collected 29/300 threads
# 200 300
# 228
# Collected 30/300 threads
# 100 200
# 104
# Collected 31/300 threads
# 100 200
# 140
# Collected 32/300 threads
# 100 200
# 154
# Collected 33/300 threads
# 50 60
# 54
# Collected 34/300 threads
# 10 20
# 16
# Collected 35/300 threads
# 100 200
# 129
# Collected 36/300 threads
# 200 300
# 205
# Collected 37/300 threads
# 100 200
# 198
# Collected 38/300 threads
# 200 300
# 228
# Collected 39/300 threads
# 30 40
# 33
# Collected 40/300 threads
# 70 80
# 79
# Collected 41/300 threads
# 100 200
# 185
# Collected 42/300 threads
# 100 200
# 156
# Collected 43/300 threads
# 10 20
# 16
# Collected 44/300 threads
# 70 80
# 78
# Collected 45/300 threads
# 200 300
# 208
# Collected 46/300 threads
# 70 80
# 75
# Collected 47/300 threads
# 80 90
# 80
# Collected 48/300 threads
# 100 200
# 170
# Collected 49/300 threads
# 80 90
# 82
# Collected 50/300 threads
# 200 300
# 289
# Collected 51/300 threads
# 50 60
# 55
# Collected 52/300 threads
# 100 200
# 167
# Collected 53/300 threads
# 100 200
# 183
# Collected 54/300 threads
# 100 200
# 153
# Collected 55/300 threads
# 60 70
# 68
# Collected 56/300 threads
# 300 400
# 322
# Collected 57/300 threads
# 100 200
# 147
# Collected 58/300 threads
# 40 50
# 42
# Collected 59/300 threads
# 90 100
# 94
# Collected 60/300 threads
# 30 40
# 38
# Collected 61/300 threads
# 800 900
# 819
# Collected 62/300 threads
# 100 200
# 190
# Collected 63/300 threads
# 50 60
# 56
# Collected 64/300 threads
# 10 20
# 12
# Collected 65/300 threads
# 100 200
# 143
# Collected 66/300 threads
# 80 90
# 84
# Collected 67/300 threads
# 1000 2559976
# 1181
# Collected 68/300 threads
# 10 20
# 19
# Collected 69/300 threads
# 30 40
# 37
# Collected 70/300 threads
# 50 60
# 59
# Collected 71/300 threads
# 100 200
# 151
# Collected 72/300 threads
# 70 80
# 77
# Collected 73/300 threads
# 90 100
# 97
# Collected 74/300 threads
# 900 1000
# 963
# Collected 75/300 threads
# 100 200
# 102
# Collected 76/300 threads
# 60 70
# 62
# Collected 77/300 threads
# 100 200
# 160
# Collected 78/300 threads
# 100 200
# 101
# Collected 79/300 threads
# 40 50
# 44
# Collected 80/300 threads
# 70 80
# 78
# Collected 81/300 threads
# 60 70
# 66
# Collected 82/300 threads
# 100 200
# 113
# Collected 83/300 threads
# 90 100
# 98
# Collected 84/300 threads
# 20 30
# 21
# Collected 85/300 threads
# 200 300
# 213
# Collected 86/300 threads
# 200 300
# 243
# Collected 87/300 threads
# 100 200
# 126
# Collected 88/300 threads
# 100 200
# 106
# Collected 89/300 threads
# 200 300
# 284
# Collected 90/300 threads
# 100 200
# 108
# Collected 91/300 threads
# 90 100
# 93
# Collected 92/300 threads
# 100 200
# 113
# Collected 93/300 threads
# 100 200
# 136
# Collected 94/300 threads
# 100 200
# 113
# Collected 95/300 threads
# 100 200
# 173
# Collected 96/300 threads
# 500 600
# 596
# Collected 97/300 threads
# 20 30
# 20
# Collected 98/300 threads
# 60 70
# 69
# Collected 99/300 threads
# 200 300
# 239
# Collected 100/300 threads
# 10 20
# 16
# Collected 101/300 threads
# 400 500
# 422
# Collected 102/300 threads
# 100 200
# 191
# Collected 103/300 threads
# 200 300
# 245
# Collected 104/300 threads
# 100 200
# 107
# Collected 105/300 threads
# 400 500
# 417
# Collected 106/300 threads
# 40 50
# 40
# Collected 107/300 threads
# 100 200
# 124
# Collected 108/300 threads
# 10 20
# 19
# Collected 109/300 threads
# 100 200
# 139
# Collected 110/300 threads
# 50 60
# 51
# Collected 111/300 threads
# 60 70
# 62
# Collected 112/300 threads
# 60 70
# 65
# Collected 113/300 threads
# 100 200
# 104
# Collected 114/300 threads
# 70 80
# 72
# Collected 115/300 threads
# 100 200
# 130
# Collected 116/300 threads
# 100 200
# 180
# Collected 117/300 threads
# 200 300
# 218
# Collected 118/300 threads
# 100 200
# 117
# Collected 119/300 threads
# 100 200
# 147
# Collected 120/300 threads
# 10 20
# 18
# Collected 121/300 threads
# 80 90
# 83
# Collected 122/300 threads
# 50 60
# 58
# Collected 123/300 threads
# 400 500
# 436
# Collected 124/300 threads
# 100 200
# 112
# Collected 125/300 threads
# 90 100
# 98
# Collected 126/300 threads
# 60 70
# 60
# Collected 127/300 threads
# 400 500
# 413
# Collected 128/300 threads
# 90 100
# 90
# Collected 129/300 threads
# 70 80
# 77
# Collected 130/300 threads
# 300 400
# 338
# Collected 131/300 threads
# 200 300
# 248
# Collected 132/300 threads
# 80 90
# 89
# Collected 133/300 threads
# 100 200
# 109
# Collected 134/300 threads
# 100 200
# 151
# Collected 135/300 threads
# 10 20
# 14
# Collected 136/300 threads
# 100 200
# 124
# Collected 137/300 threads
# 100 200
# 154
# Collected 138/300 threads
# 100 200
# 182
# Collected 139/300 threads
# 70 80
# 77
# Collected 140/300 threads
# 100 200
# 153
# Collected 141/300 threads
# 70 80
# 71
# Collected 142/300 threads
# 700 800
# 725
# Collected 143/300 threads
# 300 400
# 383
# Collected 144/300 threads
# 70 80
# 74
# Collected 145/300 threads
# 70 80
# 76
# Collected 146/300 threads
# 60 70
# 61
# Collected 147/300 threads
# 100 200
# 145
# Collected 148/300 threads
# 500 600
# 579
# Collected 149/300 threads
# 100 200
# 115
# Collected 150/300 threads
# 100 200
# 173
# Collected 151/300 threads
# 1000 2559976
# 1225
# Collected 152/300 threads
# 50 60
# 51
# Collected 153/300 threads
# 100 200
# 102
# Collected 154/300 threads
# 100 200
# 121
# Collected 155/300 threads
# 300 400
# 375
# Collected 156/300 threads
# 200 300
# 236
# Collected 157/300 threads
# 400 500
# 428
# Collected 158/300 threads
# 200 300
# 221
# Collected 159/300 threads
# 1000 2559976
# 1667
# Collected 160/300 threads
# 100 200
# 119
# Collected 161/300 threads
# 400 500
# 400
# Collected 162/300 threads
# 50 60
# 54
# Collected 163/300 threads
# 300 400
# 336
# Collected 164/300 threads
# 90 100
# 93
# Collected 165/300 threads
# 500 600
# 521
# Collected 166/300 threads
# 100 200
# 183
# Collected 167/300 threads
# 40 50
# 46
# Collected 168/300 threads
# 100 200
# 147
# Collected 169/300 threads
# 100 200
# 116
# Collected 170/300 threads
# 100 200
# 122
# Collected 171/300 threads
# 200 300
# 214
# Collected 172/300 threads
# 400 500
# 414
# Collected 173/300 threads
# 300 400
# 312
# Collected 174/300 threads
# 100 200
# 148
# Collected 175/300 threads
# 100 200
# 157
# Collected 176/300 threads
# 100 200
# 147
# Collected 177/300 threads
# 50 60
# 56
# Collected 178/300 threads
# 300 400
# 366
# Collected 179/300 threads
# 100 200
# 191
# Collected 180/300 threads
# 600 700
# 683
# Collected 181/300 threads
# 100 200
# 160
# Collected 182/300 threads
# 40 50
# 41
# Collected 183/300 threads
# 50 60
# 53
# Collected 184/300 threads
# 200 300
# 208
# Collected 185/300 threads
# 100 200
# 142
# Collected 186/300 threads
# 100 200
# 105
# Collected 187/300 threads
# 100 200
# 105
# Collected 188/300 threads
# 100 200
# 118
# Collected 189/300 threads
# 100 200
# 143
# Collected 190/300 threads
# 200 300
# 246
# Collected 191/300 threads
# 200 300
# 234
# Collected 192/300 threads
# 200 300
# 287
# Collected 193/300 threads
# 100 200
# 133
# Collected 194/300 threads
# 100 200
# 125
# Collected 195/300 threads
# 50 60
# 54
# Collected 196/300 threads
# 100 200
# 180
# Collected 197/300 threads
# 40 50
# 47
# Collected 198/300 threads
# 200 300
# 228
# Collected 199/300 threads
# 80 90
# 84
# Collected 200/300 threads
# 90 100
# 90
# Collected 201/300 threads
# 100 200
# 100
# Collected 202/300 threads
# 400 500
# 418
# Collected 203/300 threads
# 100 200
# 172
# Collected 204/300 threads
# 20 30
# 26
# Collected 205/300 threads
# 200 300
# 246
# Collected 206/300 threads
# 90 100
# 95
# Collected 207/300 threads
# 100 200
# 116
# Collected 208/300 threads
# 100 200
# 132
# Collected 209/300 threads
# 300 400
# 335
# Collected 210/300 threads
# 60 70
# 67
# Collected 211/300 threads
# 100 200
# 131
# Collected 212/300 threads
# 400 500
# 401
# Collected 213/300 threads
# 100 200
# 180
# Collected 214/300 threads
# 600 700
# 635
# Collected 215/300 threads
# 100 200
# 123
# Collected 216/300 threads
# 100 200
# 144
# Collected 217/300 threads
# 200 300
# 233
# Collected 218/300 threads
# 100 200
# 164
# Collected 219/300 threads
# 300 400
# 359
# Collected 220/300 threads
# 100 200
# 150
# Collected 221/300 threads
# 90 100
# 98
# Collected 222/300 threads
# 200 300
# 208
# Collected 223/300 threads
# 100 200
# 136
# Collected 224/300 threads
# 200 300
# 214
# Collected 225/300 threads
# 300 400
# 392
# Collected 226/300 threads
# 500 600
# 565
# Collected 227/300 threads
# 500 600
# 527
# Collected 228/300 threads
# 300 400
# 365
# Collected 229/300 threads
# 10 20
# 13
# Collected 230/300 threads
# 100 200
# 103
# Collected 231/300 threads
# 40 50
# 41
# Collected 232/300 threads
# 60 70
# 64
# Collected 233/300 threads
# 60 70
# 65
# Collected 234/300 threads
# 100 200
# 103
# Collected 235/300 threads
# 20 30
# 24
# Collected 236/300 threads
# 100 200
# 152
# Collected 237/300 threads
# 20 30
# 20
# Collected 238/300 threads
# 100 200
# 105
# Collected 239/300 threads
# 300 400
# 381
# Collected 240/300 threads
# 80 90
# 82
# Collected 241/300 threads
# 200 300
# 217
# Collected 242/300 threads
# 60 70
# 67
# Collected 243/300 threads
# 100 200
# 100
# Collected 244/300 threads
# 20 30
# 25
# Collected 245/300 threads
# 10 20
# 11
# Collected 246/300 threads
# 100 200
# 112
# Collected 247/300 threads
# 40 50
# 44
# Collected 248/300 threads
# 60 70
# 66
# Collected 249/300 threads
# 500 600
# 599
# Collected 250/300 threads
# 100 200
# 131
# Collected 251/300 threads
# 400 500
# 454
# Collected 252/300 threads
# 100 200
# 140
# Collected 253/300 threads
# 100 200
# 144
# Collected 254/300 threads
# 60 70
# 60
# Collected 255/300 threads
# 100 200
# 146
# Collected 256/300 threads
# 30 40
# 35
# Collected 257/300 threads
# 60 70
# 67
# Collected 258/300 threads
# 200 300
# 221
# Collected 259/300 threads
# 100 200
# 148
# Collected 260/300 threads
# 80 90
# 88
# Collected 261/300 threads
# 700 800
# 725
# Collected 262/300 threads
# 200 300
# 219
# Collected 263/300 threads
# 20 30
# 26
# Collected 264/300 threads
# 30 40
# 35
# Collected 265/300 threads
# 50 60
# 50
# Collected 266/300 threads
# 100 200
# 102
# Collected 267/300 threads
# 100 200
# 154
# Collected 268/300 threads
# 300 400
# 319
# Collected 269/300 threads
# 300 400
# 344
# Collected 270/300 threads
# 20 30
# 24
# Collected 271/300 threads
# 200 300
# 264
# Collected 272/300 threads
# 80 90
# 87
# Collected 273/300 threads
# 100 200
# 167
# Collected 274/300 threads
# 100 200
# 132
# Collected 275/300 threads
# 100 200
# 102
# Collected 276/300 threads
# 100 200
# 162
# Collected 277/300 threads
# 100 200
# 103
# Collected 278/300 threads
# 100 200
# 111
# Collected 279/300 threads
# 100 200
# 103
# Collected 280/300 threads
# 100 200
# 165
# Collected 281/300 threads
# 30 40
# 30
# Collected 282/300 threads
# 90 100
# 96
# Collected 283/300 threads
# 100 200
# 177
# Collected 284/300 threads
# 300 400
# 397
# Collected 285/300 threads
# 300 400
# 373
# Collected 286/300 threads
# 40 50
# 46
# Collected 287/300 threads
# 600 700
# 647
# Collected 288/300 threads
# 60 70
# 66
# Collected 289/300 threads
# 200 300
# 214
# Collected 290/300 threads
# 90 100
# 96
# Collected 291/300 threads
# 200 300
# 258
# Collected 292/300 threads
# 50 60
# 54
# Collected 293/300 threads
# 300 400
# 327
# Collected 294/300 threads
# 300 400
# 322
# Collected 295/300 threads
# 10 20
# 11
# Collected 296/300 threads
# 200 300
# 228
# Collected 297/300 threads
# 60 70
# 69
# Collected 298/300 threads
# 40 50
# 45
# Collected 299/300 threads
# 80 90
# 89
# Collected 300/300 threads
# 30 40
# 37
# Collected 301/300 threads
# 50 60
# 58
# Collected 302/300 threads
# 50 60
# 51
# Collected 303/300 threads
# 30 40
# 31
# Collected 304/300 threads
# 400 500
# 433
# Collected 305/300 threads
# 30 40
# 34
# Collected 306/300 threads
# 50 60
# 57
# Collected 307/300 threads
# 50 60
# 54
# Collected 308/300 threads
# 30 40
# 31
# Collected 309/300 threads
# 80 90
# 81
# Collected 310/300 threads
# 20 30
# 23
# Collected 311/300 threads
# 200 300
# 212
# Collected 312/300 threads
# 200 300
# 207
# Collected 313/300 threads
# 40 50
# 48
# Collected 314/300 threads
# 80 90
# 83
# Collected 315/300 threads
# 200 300
# 222
# Collected 316/300 threads
# 200 300
# 239
# Collected 317/300 threads
# 200 300
# 221
# Collected 318/300 threads
# 200 300
# 263
# Collected 319/300 threads
# 300 400
# 343
# Collected 320/300 threads
# 40 50
# 40
# Collected 321/300 threads
# 40 50
# 48
# Collected 322/300 threads
# 200 300
# 216
# Collected 323/300 threads
# 200 300
# 276
# Collected 324/300 threads
# 200 300
# 276
# Collected 325/300 threads
# 80 90
# 88
# Collected 326/300 threads
# 200 300
# 215
# Collected 327/300 threads
# 40 50
# 40
# Collected 328/300 threads
# 200 300
# 217
# Collected 329/300 threads
# 30 40
# 32
# Collected 330/300 threads
# 30 40
# 34
# Collected 331/300 threads
# 80 90
# 86
# Collected 332/300 threads
# 400 500
# 407
# Collected 333/300 threads
# 20 30
# 21
# Collected 334/300 threads
# 20 30
# 23
# Collected 335/300 threads
# 80 90
# 87
# Collected 336/300 threads
# 30 40
# 35
# Collected 337/300 threads
# 30 40
# 38
# Collected 338/300 threads
# 20 30
# 27
# Collected 339/300 threads
# 40 50
# 49
# Collected 340/300 threads
# 30 40
# 34
# Collected 341/300 threads
# 20 30
# 28
# Collected 342/300 threads
# 40 50
# 44
# Collected 343/300 threads
# 40 50
# 46
# Collected 344/300 threads
# 7 8
# 7
# Collected 345/300 threads
# 30 40
# 34
# Collected 346/300 threads
# 30 40
# 33
# Collected 347/300 threads
# 20 30
# 24
# Collected 348/300 threads
# 9 10
# 9
# Collected 349/300 threads
# 6 7
# 6
# Collected 350/300 threads

# %%
print(found_count)
print(ids)
# Out:
# [   0.    0.    0.    0.    0.    1.    1.    0.    1.   12.   15.   17.
#    17.   18.   18.   16.   16.   14.  106.   48.   21.   12.    6.    3.
#     3.    1.    1.    3.]
# [17390, 24218, 12245, 23253, 26252, 1943, 14620, 15254, 5201, 2130, 21304, 20745, 15493, 5433, 27208, 17751, 21346, 19675, 8969, 4675, 11926, 5565, 24282, 20421, 9046, 25367, 14351, 4067, 19938, 12145, 10825, 26863, 8876, 11792, 2906, 22950, 24999, 14748, 25375, 9504, 5185, 6594, 6869, 27489, 17848, 260, 9988, 5527, 4972, 27264, 11724, 9993, 2673, 4892, 24873, 553, 19790, 17816, 10375, 7145, 26387, 26178, 24452, 1944, 18112, 1919, 6751, 20283, 7880, 7014, 10706, 28129, 4652, 27168, 16617, 17481, 15284, 2550, 11783, 20726, 27538, 22565, 16536, 22092, 20292, 2430, 10317, 12223, 11834, 23070, 15999, 21050, 11462, 4382, 17027, 13206, 13524, 8602, 7131, 5521, 3899, 10841, 3112, 26879, 1961, 15919, 20883, 15333, 12800, 23631, 27430, 7224, 2898, 21531, 21831, 22225, 6536, 6056, 10980, 8182, 12935, 21803, 11254, 490, 3813, 11449, 22987, 25902, 22637, 23448, 2702, 25586, 8918, 24062, 28672, 23309, 454, 28010, 3037, 23038, 766, 22747, 18316, 7963, 417, 18501, 21253, 14002, 11722, 16465, 2203, 5337, 9779, 1897, 9000, 2754, 1218, 7659, 7359, 17423, 15075, 6832, 9224, 18118, 4927, 22193, 20156, 17767, 23452, 15865, 23072, 24288, 26278, 14643, 13943, 10542, 20482, 14055, 15486, 7687, 18704, 22203, 8688, 4787, 25338, 28668, 9011, 15781, 15963, 18209, 19823, 18044, 6783, 13709, 26731, 13648, 15613, 8364, 5121, 4612, 26421, 13281, 17249, 25385, 9732, 12316, 16150, 16307, 560, 10059, 15775, 2856, 15208, 20275, 23601, 19420, 15489, 3904, 27421, 26175, 28101, 24665, 26301, 19617, 18764, 21107, 26250, 7024, 15150, 14258, 20493, 14931, 25864, 2328, 14248, 599, 21743, 10412, 8792, 2538, 10536, 24008, 3757, 1132, 25612, 1130, 23410, 12190, 24482, 23806, 15920, 11278, 22460, 10824, 22112, 4169, 26233, 14877, 1465, 9815, 20685, 1876, 18633, 2343, 22293, 5668, 11623, 22394, 6149, 21167, 15347, 23951, 5699, 2699, 15114, 6154, 28224, 13551, 20827, 17522, 921, 15003, 25069, 18672, 8646, 7017, 24119, 5039, 8831, 15127, 12063, 14340, 23348, 4387, 26817, 27977, 17437, 18848, 12844, 6759, 9343, 20628, 4437, 24747, 4205, 24346, 28179, 17073, 11331, 24463, 2249, 2040, 8533, 5685, 3941, 2418, 19654, 714, 26798, 10878, 12869, 24896, 6248, 5205, 26150, 28230, 18023, 9693, 10404, 2056, 25483, 22485, 5528, 12366, 31, 943, 19239, 12891, 19496, 15760, 10023, 3851, 19041, 23735, 11633, 10023, 22103, 8092, 12832, 8483]

# %%
# write training data to .csv
import csv
with open('posts.csv', 'w') as csvfile:
    spamwriter = csv.writer(csvfile)
    i = 1
    spamwriter.writerow(["index", "thread_id", "title", "url", "post time", "post body", "word count"])
    for id in ids:
        thread = session.query(Thread).get(id)
        spamwriter.writerow([i, id, thread.title, thread.url, thread.timestamp, thread.body, word_count(thread.body)])
        i += 1

# %%
# write repleis to threads to .csv
import csv
with open('replies_to_threads.csv', 'w') as csvfile:
    spamwriter = csv.writer(csvfile)
    spamwriter.writerow(["number of replies"])
    for posts in thread_posts_1:
        spamwriter.writerow([posts])
