# %%
import numpy as np
from numpy import loadtxt

# %%
from collections import Counter
[k for k,v in Counter(slang).items() if v>1]
# Out:
# ['BTW', 'sup', 'thx', 'ur', 'BRB', 'u', 'l8r', 'm8']

# %%
def get_items(filename, comment=None):
    if not comment:
        #print("not comment")
        comment = ";"
    items = []
    import codecs
    with open(filename, encoding='ISO-8859-1') as file:
        for line in file:
            if line[0] == comment:
                continue
            else:
                line = ' '.join(line.split())
                items.append(line.split(" ")[0])
    # then delete duplicates if any
    seen = set()
    uniq = [x for x in items if x not in seen and not seen.add(x)] 
    return uniq

# %%
slangs = get_items("lists/internet-slang-merge.txt")

# %%
slangs
# Out:
# ['Dunno',
#  '<3',
#  '@',
#  '1',
#  '2',
#  '4',
#  '4n',
#  'Aight',
#  'B4',
#  'B',
#  'Bb',
#  'BRB',
#  'BTW',
#  'C',
#  'cuz,',
#  'da',
#  'dat',
#  'der',
#  'gonna',
#  'k',
#  'kay',
#  'kwl',
#  'kewl',
#  'kool',
#  'l8r',
#  'm8',
#  'mrlk',
#  'nvm',
#  'o',
#  'O3',
#  'pic',
#  'plz,',
#  'pls',
#  'shud',
#  'shudda,',
#  'shoulda',
#  'sup',
#  'soz,',
#  'sry,',
#  'srry',
#  'tho',
#  'thnx',
#  'thx',
#  'ty',
#  'u',
#  'ur',
#  'w8',
#  'wanna,',
#  'wan2',
#  'wd',
#  'ye',
#  'Yo',
#  'AFAIC',
#  'AFAICS',
#  'AFAIK',
#  'AFAIR',
#  'AFK',
#  'ASAP',
#  'ASL?',
#  'AYH?',
#  'AYBABTU',
#  'AYFS',
#  'BBIAB',
#  'BBL',
#  'BBS',
#  'BD',
#  'BRT',
#  'COL',
#  'CSWS',
#  'CU',
#  'CUL',
#  'CYA',
#  'CYS',
#  'DIAF',
#  'DFTBA',
#  'EOM',
#  'FAQ',
#  'FFS',
#  'FOAD',
#  'FML',
#  'FWIW',
#  'FTL',
#  'FTW',
#  'FTUW',
#  'FTMFW',
#  'FYI',
#  'G2G',
#  'GTG',
#  'GAGF',
#  'GAL',
#  'GFY',
#  'GG',
#  'GIYF',
#  'GTFO',
#  'GTH',
#  'HAND',
#  'HTH',
# ...

# %%
female_names = get_items("lists/female-names.txt")
female_names
# Out:
# not comment
# ['AARON',
#  'ABBEY',
#  'ABBIE',
#  'ABBY',
#  'ABIGAIL',
#  'ADA',
#  'ADAH',
#  'ADALINE',
#  'ADAM',
#  'ADDIE',
#  'ADELA',
#  'ADELAIDA',
#  'ADELAIDE',
#  'ADELE',
#  'ADELIA',
#  'ADELINA',
#  'ADELINE',
#  'ADELL',
#  'ADELLA',
#  'ADELLE',
#  'ADENA',
#  'ADINA',
#  'ADRIA',
#  'ADRIAN',
#  'ADRIANA',
#  'ADRIANE',
#  'ADRIANNA',
#  'ADRIANNE',
#  'ADRIEN',
#  'ADRIENE',
#  'ADRIENNE',
#  'AFTON',
#  'AGATHA',
#  'AGNES',
#  'AGNUS',
#  'AGRIPINA',
#  'AGUEDA',
#  'AGUSTINA',
#  'AI',
#  'AIDA',
#  'AIDE',
#  'AIKO',
#  'AILEEN',
#  'AILENE',
#  'AIMEE',
#  'AISHA',
#  'AJA',
#  'AKIKO',
#  'AKILAH',
#  'ALAINA',
#  'ALAINE',
#  'ALANA',
#  'ALANE',
#  'ALANNA',
#  'ALAYNA',
#  'ALBA',
#  'ALBERT',
#  'ALBERTA',
#  'ALBERTHA',
#  'ALBERTINA',
#  'ALBERTINE',
#  'ALBINA',
#  'ALDA',
#  'ALEASE',
#  'ALECIA',
#  'ALEEN',
#  'ALEIDA',
#  'ALEISHA',
#  'ALEJANDRA',
#  'ALEJANDRINA',
#  'ALENA',
#  'ALENE',
#  'ALESHA',
#  'ALESHIA',
#  'ALESIA',
#  'ALESSANDRA',
# ...
